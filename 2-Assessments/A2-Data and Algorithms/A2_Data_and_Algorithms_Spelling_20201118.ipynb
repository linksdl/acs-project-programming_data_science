# %% [markdown]
# ## P4DS: Assignment 2 (Autumn 2020)
#
# # Data and Algorithms, Part II
#
#
# ## Q3. Write a simple spell-checker (10 marks)
#
# To answer this question, you need to write a function ```spell_check_file```, which takes
# one argument that is the name of a file and prints output similar to that given below, showing all words in the file that may be spelling mistakes. More specifically,
# for each line where _potential spelling mistakes_ are identified, it should
# ``print`` out the line number followed by a list of the words that have been identified
# as possibly misspelled.
#
# Thus the output should be similar to
# (but not necessarily in the exact same format as) the following, which I obtained by running
# my code on the file `spelling.txt`:
#
# <pre>
#     3 : ['primarry', 'secondarry']
#     4 : ['recieved', 'Phisics']
#     5 : ['Comunication', 'Religeon', 'll']
#     8 : ['ambigous']
#     9 : ['cource']
#    10 : ['atempt', 'commprehend', 'Luckilly']
#    12 : ['aquainted', 'langauge']
#    13 : ['simillar']
#    14 : ['paticular']
#    22 : ['expresion']
#    23 : ['expresive']
# </pre>
#
# ### Important note on output form
# Please not that (unlike Assignment 1 and Part I of Assignment 2)
# for this quesiton your code should actually display the output
# using `print` statements. That is because this question
# will not be marked by an autograder. We
# shall actually be looking at your code and running it, and it
# will be easier for us to interpret nicely formatted output than
# a big datastructure. Also it gives you a little bit of practice
# in formatting.
#
# #### Assumptions:
# You may assume the following:
# * The file to be tested is in the same folder as your program       file, and the correct file name is always given as
#   the argument to `spell_check_file`.
# * The file `english_words.txt` is also in the same folder.
# * The input file is in ASCII encoding (or in a UTF-8 encoding
#   that can be treated as ASCII).*
#
# ####  \*Note on encodings:
# The fact that files can use different character encodings can
# potentially cause problems for this kind of functionality.
# Hence, I will only test on ASCII files. Many files are actually
# formatted using more complex encodings. But many files that
# are specified as being UTF-8 can be treated as ASCII.
# In fact ASCII files can, in nearly all cases, be considered
# to be in UTF-8. (Techinically ASCII is a 7-bit encoding, which
# means that it has a spare bit that is not used but is
# used by UTF-8 to extend ASCII to much larger character sets. However, in rare cases software working with ASCII could use the
# spare 8th bit of an ASCII byte for some special purpose. This
# would mess up the UTF-8 interpretation of the file. But one
# could then just set all the spare bits to 0, which would turn
# it to UTF-8 that is equivalent to the original ASCII).
#
# A very good article on character encodings by Stack Exchange co-founder Joel Spolsky [here](https://www.joelonsoftware.com/2003/10/08/the-absolute-minimum-every-software-developer-absolutely-positively-must-know-about-unicode-and-character-sets-no-excuses/)
#
# The books files in the module [data repository](https://teaching.bb-ai.net/P4DS/data/index.html) are in plain ASCII (apart from the book Antic Hay (which is in UTF-8-SIG). You may also be interested to download addtional book data from [Project Gutenberg](https://www.gutenberg.org/), which is
# a nice resource for people interested in classic books.
# The file format used there is actually `UTF-8-SIG`, which is
# basically just `ASCII` but with a special extra byte (a [BOM](https://en.wikipedia.org/wiki/Byte_order_mark)) at the
# beginning of the file. This probably will not cause a problem,
# but, if it does, it is fairly easy to remove this first byte.

# %% [markdown]
# ### Code Restrictions and Size Limits
#
# Your code should be written within this file and the name of the file
# should not be changed.
#
# I am looking for a self-contained, simple and concise piece of code which does a reasonable job of identifying potential spelling mistakes.
# Hence, Your code should satisfy the following limiations:
# * It should __not__ `import` any modules.
# * It should __not__ make use of any functions or constants defined
#   in other cells.
# * It should __not__ exceed 50 lines of code but blank lines and lines that
#   define a function (i.e. start with `def`) are not included.
# * It should __not__ contain any line longer than 80 characers wide.
#
# My solution, that produced the output shown above, falls well within these
# restrictions, consisting of 16 lines of code. However, my code could
# certainly be improved with some additional checks.
#
# The reason that `def` lines are excluded is that it is nearly always
# a good idea to break down a complex function into simpler parts. So you
# will not use up the line limit by doing this. In particular,
# you will need a function like `get_english_words` to
# get read the words from the `english_words.txt` file;
# and it is probably
# a good idea to have a function that checks words (similar to the
# `is_english_word` function), which is separtate from
# the main function that processes the whole file.
#
#
# ### Notes and Sugestions
#
# I have not specified exactly which strings in the input file should
# be counted as _"potential spelling mistakes"_. This is intentended, since I want
# you to think of the problem as one of real data handling, rather than a purely
# artificial exercise. Like many real problems involving manipulation of real data,
# exact criteria that determine its interpretation and classification may be difficult
# or even impossible to state precisely. In such cases, we typically start with
# an intuitive idea of what we want to do with the data, and soon realise that
# we have to make this more precise to actually implement a solution. We then
# try to specify the details of the processing required and results we want to
# obtain. After some analysis and consideration of examples, we can usually
# come up with a speicification that works well and gives useful
# results in nearly all cases. However, for a real problem involving
# a complex real data sorce, it is unlikely that we can find a solution that
# gives useful and desirable results in 100% of cases.
#
# #### Some useful functions to construct a simple solution
#
# Clearly, the `is_english_word` function that you defined in the previous
# assignment, or something similar, will be very useful.
# You may assume that any English word is not a spelling mistake.
#
# The following basic Python built-in functions are very useful for manipulating
# raw data:
# * `tokens = s.split()` --- Use this kind of construct to chop a string (or whole
#    document contents into parts. Given no arguments it will split a string at
#    all points where there is whitespace (spaces, tabs and/or newlines).
# * `s = s.strip()`  --- This construct will replace `s` by a cleaned up version
#    with no whitespace at either end (but can be in the middle).
# * `s = s.replace(x,y)` --- replace all occurrences of `x` with `y` in the string
#     `s`, where `x` and `y` can be either single characters or strings.
# * `s = s.replace(x,'')` --- replace all occurrences of `x` in `s` by nothing
#    --- i.e. delete them.
#
# #### Issues to deal with
#
# * Punctuation --- this presents an immediate problem, especially since punctuation
#   symbols may occur directly before or after a word. Worse still, certain punctuation
#   marks such as hypens and apostrophes may occur within a word. Many cases can be
#   dealt with by simply deleting punctuation symbols, but this is by no means a perfect
#   solution.
#
# * Odd capitalisation --- our `is_english_word` function assumes that an English word must be either: all lower case, all uppoer case, or, start with an upper case letter and have
# the rest all lower. This is quite a good rule but different forms are sometimes used
# (for example `eBook`).
#
# * Unusual or colloquial words --- clearly many books contain
#   peculiar non-standard words, especially in quoted speech.
#
# * Proper names. Typically, these start with a capital letter; but how can you tell
#   a proper name from a wrongly spelled word that is capitalised because it is at the
#   beginning of a sentence? There is no easy way.
#
# * Runtime --- checking words against a list of corret English words can take a long
#   time if every word is being checked against every word in the list. However,
#   most of this time is unnecessary. Preprocessing of a list can enable one to tell
#   much more quickly whether it contains a given element.
#
# I do not expect your code to perfectly solve any of these problems, but try to deal
# with them as best you can given the code length restrictions given above and the
# limited time you have available.

# %% [markdown]
# ### Marks Guidline
# The 10 marks are assigned according to the overall quality
# of your solution. They will normally be allocated according to the following proportions:
#
# * Basic functionality and output format (4 marks)
# * Accuracy in identifiying incorrect words (compared to
#   reasonable expectations) (5)
# * Speed performance on a large text (1)

# %% [markdown]
# ### Please put all your code of your answer in the following cell

# %%
# Q3 answer code cell
# Modify this function definition to fulfill the given requirements.
# Maximum code length: 50 lines

# Get all English words set.
def get_english_words():
    with open("english_words.txt") as f:
        words = f.readlines()
    words = {word.strip() for
             word in words}
    return words

# all words set
ENGLISH_WORDS = get_english_words()

# Determine if a word is an english word.
def is_english_word(s):
    return True if (s.islower() or s.istitle() or s.isupper()) and s.lower() in ENGLISH_WORDS else False


print(is_english_word('Which'))

def count_words(words):
    dicts = {}
    for key in words:
        dicts[key] = dicts.get(key, 0) + 1
    dicts = sorted(dicts.items(), key=lambda x: x[1], reverse=True)  
    return dicts

# compute reliability of every word
def compute_word_reliability(n, word_count):
    # 1. If the word is in english_words, then the reliability is 100
    # 2. If the number of word occur in text more than n and less than 16, the reliability range in [50, 90)
    # 3. if the number of word occur in text more than 16, the reliability >= 90
    word_reliability = {}
    for k, v in word_count.items():
        if k != '' and is_english_word(k):
            w = {k: 100}
        elif v >= 16:
            w = {k: 90 + (v - 15) * 1}
        elif n <= v < 16:
            w = {k: 50 + (v - n) * 3}
        else:
            w = {k: v * 10}
        word_reliability.update(w)

    return word_reliability

# spell checking function
def spell_check_file(filename):
    # Open the source text
    with open(filename) as f:
        lines = f.readlines()

    special_char = ',;!?_()"*[]{}&#=>'
    words_count = {}
    list_lines = []
    number_for_reliable = 3
    score_for_reliable = 50
    for i in range(len(lines)):
        line = lines[i]
        # step1, remove the special char in the text
        for char in special_char:
            line = line.strip().replace(char, ' ').replace('--', ' ').replace('...', ' ').replace(".'", ' ')
        list_line = (' '.join(line.split())).split(' ')

        # step2, remove the special char in the word
        for j in range(len(list_line)):
            if len(list_line[j]) > 0 and (
                    list_line[j][-1] == '.' or list_line[j][-1] == ':' or list_line[j][-1] == "'"):
                list_line[j] = list_line[j][:-1]

            if len(list_line[j]) > 0 and ( list_line[j][0] == "'" or list_line[j][0] == '“'):
                list_line[j] = list_line[j][1:]

        for k, v in count_words(list_line):
            temp = {k: words_count.get(k) + v} if k in words_count else {k: v}
            words_count.update(temp)

        list_lines.append(list_line)

    # compute the every word reliability.
    words_reliability = compute_word_reliability(number_for_reliable, words_count)
    print('line number : [{word, reliability-score}, ...]')
    for j in range(len(list_lines)):
        list_line = list_lines[j]
        spcial_words = ["'s", "'d", "'t", "'ll", "'ve", "-", "www.", "http:", ".org"]
        common_words = ["the"]
        # step3, remove the special words and digit base on the special words list
        for k in range(len(spcial_words)):
            w = spcial_words[k]
            list_line = [ls for ls in list_line if not w in ls and not ls.isdigit()]
            
        error_words = []
        for lw in list_line:
            if len(lw) > 1 and words_reliability.get(lw) < score_for_reliable:
                d = {lw: words_reliability.get(lw)}
                error_words.append(d)

        
        if len(error_words) > 0:
            print(j, ':', error_words)
# Out:
# True

# %% [markdown]
# ### `spell_check_file` testing
# Run the following cell to run your `spell_check_file` function on the
# example file `spelling.txt` and see the result.
#
# * Download [`spelling.txt`](https://teaching.bb-ai.net/P4DS/data/spelling.txt)
#
# You may want to also test your `spell_check_file` function with some other
# longer examples. But please
# delete such tests from the final version you submit, since your
# code will give an error if it tries to load an external file.
#
# Please leave the ``%%time`` instruction, which causes Jupyter
# to measure and display the execution time of your code.

# %%
# %%time
spell_check_file("Antic-Hay.txt")
# Out:
# line number : [{word, reliability-score}, ...]
# 0 : [{'\ufeffThe': 10}]
# 16 : [{'October': 10}]
# 27 : [{'Tonsing': 20}]
# 30 : [{'Internet': 20}]
# 55 : [{'VICTORIANS': 10}]
# 58 : [{'Arnold': 20}, {'Bennett': 20}]
# 59 : [{'ALLAH': 10}, {'Hilaire': 10}, {'Belloc': 10}]
# 60 : [{'vol': 10}, {'Garnett': 20}]
# 63 : [{'Milne': 20}]
# 64 : [{'CROME': 10}]
# 65 : [{'Clive': 10}]
# 69 : [{'Julian': 10}]
# 70 : [{'Hughes': 10}]
# 72 : [{'Milne': 20}]
# 74 : [{'SAILOR’S': 10}, {'Garnett': 20}]
# 76 : [{'MR': 20}, {'WESTON’S': 10}, {'Powys': 10}]
# 77 : [{'WILLOWES': 10}, {'Sylvia': 10}, {'Townsend': 10}]
# 79 : [{'Arnold': 20}, {'Bennett': 20}]
# 80 : [{'TARR': 10}, {'Wyndham': 10}]
# 81 : [{'MEXICAN': 10}]
# 84 : [{'Martin’s': 10}]
# 95 : [{'ALDOUS': 10}, {'HUXLEY': 10}]
# 99 : [{'CHATTO': 10}, {'WINDUS': 10}]
# 100 : [{'LONDON': 10}]
# 105 : [{'November': 20}]
# 108 : [{'Britain': 10}]
# 115 : [{'Marlowe': 10}]
# 128 : [{'B.A': 20}, {'Oxon': 10}]
# 136 : [{'Deuteronomy': 10}]
# 138 : [{'Israel': 10}]
# 140 : [{'Lord.”': 20}]
# 143 : [{'theography': 10}, {'theometry': 10}, {'theognomy': 10}]
# 144 : [{'theotrophy': 10}, {'theotomy': 10}, {'theogamy': 10}, {'theophysics': 10}]
# 145 : [{'theotrope': 10}]
# 146 : [{'theodrome': 10}]
# 149 : [{'Goliath’s': 10}]
# 150 : [{'narwhal’s': 10}]
# 151 : [{'giant’s': 10}]
# 154 : [{'might.”': 10}]
# 159 : [{'thought—that': 10}, {'4—that': 10}]
# 162 : [{'M.A': 10}]
# 168 : [{'heart.”': 20}]
# 174 : [{'sittest': 10}, {'walkest': 10}]
# 175 : [{'liest': 10}, {'risest': 10}, {'up.”': 20}]
# 178 : [{'‘Beetles': 10}]
# 179 : [{'beetles’—his': 10}]
# 180 : [{'Mumbojumbery': 10}]
# 190 : [{'simpatica': 10}, {'—how': 10}]
# 192 : [{'—but': 10}]
# 197 : [{'filledst': 10}]
# 198 : [{'diggedst': 10}]
# 199 : [{'plantedst': 10}]
# 201 : [{'died—but': 10}]
# 202 : [{'later—of': 10}]
# 203 : [{'disease—oh': 10}, {'caro': 10}]
# 219 : [{'day.”': 10}]
# 224 : [{'endeth': 20}, {'Lesson.”': 10}]
# 225 : [{'Deum': 10}]
# 227 : [{'B.A': 20}]
# 237 : [{'teacher’s': 10}, {'comrades’': 10}]
# 247 : [{'Luke': 10}]
# 248 : [{'unvaryingly': 10}]
# 257 : [{'pneu': 10}]
# 259 : [{'endeth': 20}]
# 262 : [{'Benedictus': 10}]
# 265 : [{'Spartans': 10}]
# 279 : [{'best—and': 10}, {'largest—is': 10}]
# 283 : [{'Amen.”': 10}]
# 286 : [{'Dunlop': 10}]
# 289 : [{'Pelvey’s': 10}]
# 291 : [{'words—those': 10}]
# 292 : [{'oboeing': 10}, {'existence—were': 10}]
# 295 : [{'ground.”': 10}]
# 297 : [{'salvation.”': 20}]
# 299 : [{'genuflectory': 10}]
# 302 : [{'up—and': 10}]
# 303 : [{'Greeks': 20}]
# 308 : [{'Sundays': 10}]
# 314 : [{'ONE—2': 10}, {'ONE—2—3—4': 20}]
# 315 : [{'ONE—2—3—4': 20}]
# 318 : [{'example’s': 10}]
# 325 : [{'mf': 10}]
# 326 : [{'ff': 20}]
# 330 : [{'Tempter’s': 10}]
# 332 : [{'ff': 20}]
# 333 : [{'pp': 10}]
# 336 : [{'Austin': 10}]
# 337 : [{'work—not': 10}]
# 348 : [{'verse.”': 10}]
# 350 : [{'Ephesians.”': 10}]
# 361 : [{'master’s': 10}]
# 366 : [{'European': 10}, {'history.”': 10}]
# 379 : [{'eyebrows—“will': 10}]
# 380 : [{'cutting.”': 10}]
# 405 : [{'1899—oh': 10}, {'—he': 10}]
# 413 : [{'Sadler': 20}]
# 414 : [{'Sadler': 20}]
# 418 : [{'time—ah': 10}]
# 419 : [{'since—with': 10}]
# 421 : [{'Vickers': 20}, {'Vickers': 20}]
# 422 : [{'‘come': 10}, {'out’—': 10}]
# 423 : [{'pyogenes': 10}, {'adolescence—with': 10}]
# 427 : [{'Pio': 20}, {'Nono': 10}]
# 428 : [{'Falarope': 20}]
# 429 : [{'Ferretti': 10}]
# 433 : [{'syllabus.”': 10}]
# 434 : [{'Falarope': 20}]
# 435 : [{'Higgs': 10}]
# 438 : [{'armistice.”': 10}, {'Beddoes': 10}]
# 440 : [{'intelligence.”': 10}, {'Sopwith': 10}, {'Pio’s': 10}]
# 443 : [{'Antonelli': 10}]
# 444 : [{'Metternich': 20}]
# 446 : [{'Cavour': 10}]
# 447 : [{'amnesty.”': 10}, {'Garstang’s': 10}]
# 451 : [{'précis.”': 10}, {'précis': 10}]
# 452 : [{'Appleyard': 10}]
# 463 : [{'money—that': 10}, {'it—money': 10}]
# 477 : [{'Maillols': 10}]
# 478 : [{'Goyas': 10}, {'Boucher': 10}]
# 479 : [{'Piazzetta': 10}]
# 483 : [{'Daumiers': 10}]
# 484 : [{'Tiepolos': 10}, {'Canaletto': 10}, {'Picasso': 20}]
# 485 : [{'Ingres': 10}]
# 490 : [{'rubadub—adubadub': 10}]
# 493 : [{'women—how': 10}, {'—they': 20}]
# 496 : [{'Phyllis': 20}]
# 498 : [{'Phyllis': 20}]
# 506 : [{'Athens': 10}, {'Seville': 10}, {'Unamuno': 10}, {'Papini': 10}]
# 509 : [{'Schoenberg': 10}]
# 520 : [{'Anglican': 10}]
# 526 : [{'Dinner’s': 10}]
# 529 : [{'ignobler': 10}]
# 532 : [{'indistinguishable': 10}]
# 542 : [{'behind—or': 10}]
# 548 : [{'II': 10}]
# 552 : [{'Paddington': 20}]
# 558 : [{'maisonnettes': 10}]
# 578 : [{'birdless': 10}]
# 618 : [{'son’s': 20}]
# 621 : [{'undishevelled': 10}]
# 635 : [{'schoolmaster.”': 20}]
# 638 : [{'well.”': 10}]
# 643 : [{'imagine.”': 10}]
# 648 : [{'pedagogue’s': 10}]
# 655 : [{'anything——”': 10}]
# 660 : [{'nothing.”': 20}]
# 664 : [{'schoolmaster.”': 20}]
# 667 : [{'profession.”': 10}]
# 676 : [{'themselves.”': 10}]
# 680 : [{'wanted.”': 10}]
# 687 : [{'universe—what': 10}]
# 688 : [{'understand—why': 10}]
# 690 : [{'education.”': 10}]
# 696 : [{'mayn’t': 10}]
# 699 : [{'apes—not': 10}]
# 701 : [{'up—or': 10}]
# 702 : [{'up—dancing': 10}, {'Bernard': 20}]
# 703 : [{'‘Vigilet': 10}, {'tota': 10}, {'nocte': 10}, {'luxuriosus': 10}, {'patienter’': 10}]
# 704 : [{'‘sed': 10}, {'libenter': 10}, {'suam': 10}, {'expleat': 10}]
# 705 : [{'voluptatem.’': 10}]
# 706 : [{'Latin.”': 10}]
# 710 : [{'evening—encouraging': 10}]
# 712 : [{'writers’': 10}]
# 714 : [{'‘Essays’': 10}]
# 717 : [{'Latin—that’s': 10}]
# 718 : [{'Heaven’s': 10}]
# 724 : [{'important.”': 20}]
# 725 : [{'important.”': 20}]
# 727 : [{'novissima': 10}, {'tempora': 10}, {'pessimma': 10}, {'sunt': 10}, {'vigilemus': 10}]
# 728 : [{'Damianus': 10}]
# 757 : [{'Browning’s': 10}]
# 758 : [{'‘Grammarian.’': 10}]
# 760 : [{'Balbulus': 10}]
# 761 : [{'Bernard': 20}]
# 769 : [{'fame—even': 10}]
# 777 : [{'service.”': 20}]
# 783 : [{'me—the': 10}]
# 788 : [{'sedentary”': 10}]
# 790 : [{'civilization’s': 10}, {'steatopygism': 10}]
# 793 : [{'Lectulus': 10}, {'Dei': 20}, {'floridus': 10}]
# 795 : [{'Gazophylacium': 10}, {'Ecclesiæ': 10}]
# 796 : [{'benesonans': 10}, {'Dei': 20}]
# 797 : [{'Cymbalum': 10}, {'jubilationis': 10}, {'Christi': 10}]
# 798 : [{'Promptuarium': 10}, {'mysteriorum': 10}, {'fidei': 10}, {'nobis': 10}]
# 807 : [{'inflateable': 10}]
# 809 : [{'cloth.”': 10}]
# 813 : [{'Gumbrils': 10}]
# 814 : [{'lot.”': 10}]
# 820 : [{'done.”': 10}]
# 822 : [{'right”': 10}]
# 824 : [{'Flo': 10}]
# 839 : [{'tobacconist’s': 20}, {'stock—he’s': 10}]
# 848 : [{'trying.”': 10}]
# 850 : [{'He’ll': 10}]
# 856 : [{'if—why': 10}]
# 858 : [{'afternoon.”': 20}]
# 861 : [{'be—this': 10}]
# 864 : [{'spend.”': 10}]
# 873 : [{'gardens—you': 10}, {'—protected': 10}]
# 874 : [{'maids’': 20}]
# 877 : [{'maids’': 20}]
# 881 : [{'roof’s': 10}]
# 890 : [{'house.”': 10}]
# 894 : [{'Jerusalem': 10}]
# 900 : [{'late.”': 20}]
# 908 : [{'fellow.”': 10}]
# 914 : [{'Poverty’s': 10}]
# 917 : [{'got.”': 10}]
# 929 : [{'properly.”': 10}]
# 933 : [{'lately.”': 10}]
# 956 : [{'enthusiastically': 20}]
# 963 : [{'these.”': 10}, {'Chatsworths': 10}]
# 965 : [{'Peter’s': 10}, {'example.”': 20}]
# 970 : [{'look.”': 10}]
# 977 : [{'façade': 10}]
# 982 : [{'doorway—all': 10}]
# 984 : [{'Darius': 10}]
# 986 : [{'Behistun—unexpected': 10}]
# 987 : [{'emptiness.”': 10}]
# 993 : [{'palazzo.”': 10}]
# 995 : [{'true.”': 10}]
# 997 : [{'sun—where': 10}]
# 1001 : [{'Barbados': 10}]
# 1010 : [{'inside.”': 10}]
# 1012 : [{'inwards—into': 10}]
# 1018 : [{'front.”': 10}]
# 1025 : [{'Elizabethan': 20}]
# 1035 : [{'Bletchley': 10}]
# 1039 : [{'architecture—which': 10}]
# 1046 : [{'giants—when': 10}]
# 1050 : [{'Alberti—Alberti': 10}]
# 1054 : [{'Plutarch': 10}, {'Cato': 10}]
# 1055 : [{'Brutus': 10}]
# 1059 : [{'Brunelleschi': 10}]
# 1064 : [{'Palladio': 10}, {'these——”': 10}]
# 1069 : [{'bed.”': 20}]
# 1074 : [{'III': 10}]
# 1082 : [{'mine.”': 20}]
# 1098 : [{'look—how': 10}, {'—well': 10}]
# 1099 : [{'negleejay.”': 10}]
# 1102 : [{'Negleejay': 10}]
# 1104 : [{'—no': 10}]
# 1107 : [{'hat—didn’t': 10}]
# 1109 : [{'clothes—garments': 10}]
# 1110 : [{'—through': 10}, {'tailor’s': 20}]
# 1112 : [{'Hélène': 10}]
# 1113 : [{'Fourmont': 10}, {'Rubens’s': 10}, {'Vienna': 10}]
# 1117 : [{'picture—such': 10}]
# 1123 : [{'idea.”': 10}]
# 1129 : [{'you—if': 10}]
# 1143 : [{'cleeantail': 10}]
# 1144 : [{'’ardly': 10}]
# 1145 : [{'things.”': 20}]
# 1147 : [{'Couldn’t': 10}]
# 1150 : [{'Well.”': 10}]
# 1156 : [{'bourgeois—oh': 10}]
# 1164 : [{'wrong.”': 10}]
# 1166 : [{'Gumbril—the': 10}]
# 1167 : [{'it—it': 10}]
# 1168 : [{'that’ll': 10}]
# 1172 : [{'‘towel.’': 10}, {'‘towel': 10}]
# 1175 : [{'That’ll': 20}]
# 1176 : [{'‘tèaul': 10}, {'it’ll': 20}, {'‘Pass': 10}]
# 1177 : [{'Proletariat.’': 10}, {'Tèaul.”': 10}]
# 1186 : [{'can’t—it’s': 10}]
# 1187 : [{'galling.”': 10}]
# 1205 : [{'whatever.”': 10}]
# 1216 : [{'liberty.”': 10}]
# 1222 : [{'Women—always': 10}]
# 1223 : [{'Who’s': 20}]
# 1225 : [{'’atched': 10}, {'’ole': 10}]
# 1226 : [{'Shelley': 10}, {'it—it’s': 10}]
# 1227 : [{'reelly': 10}, {'liberty’s': 10}]
# 1229 : [{'working—mostly': 10}]
# 1230 : [{'wanted—or': 10}]
# 1231 : [{'want—they': 10}]
# 1235 : [{'hyjeenic': 10}]
# 1236 : [{'slavery—the': 10}]
# 1245 : [{'’appened': 10}]
# 1249 : [{'’im': 10}]
# 1253 : [{'telephones—take': 10}]
# 1254 : [{'youself': 10}]
# 1256 : [{'’ypothetical': 20}]
# 1258 : [{'’ypothetical': 20}]
# 1260 : [{'now—why': 10}]
# 1263 : [{'freedom—what’s': 10}]
# 1265 : [{'’orrible': 20}, {'’ideous': 10}]
# 1272 : [{'’oax': 10}, {'’orrible': 20}]
# 1274 : [{'swindle.”': 10}]
# 1283 : [{'dad—a': 10}]
# 1284 : [{'Gumbril—he': 10}]
# 1285 : [{'Gloire': 10}, {'Dijon': 10}]
# 1289 : [{'what’ll': 10}, {'roses—’oo': 10}]
# 1290 : [{'’oo': 20}]
# 1296 : [{'Tuesday': 10}]
# 1298 : [{'Tuesday.”': 10}]
# 1299 : [{'Bojanus.”': 10}]
# 1306 : [{'Hanover': 20}]
# 1320 : [{'Grosvenor': 10}]
# 1325 : [{'Sotheby’s': 10}]
# 1330 : [{'‘Forthcoming': 10}, {'Lypiatt.’': 10}]
# 1339 : [{'etcher’s': 10}]
# 1346 : [{'imberb': 10}]
# 1353 : [{'flat—though': 10}]
# 1360 : [{'finished.”': 10}]
# 1376 : [{'intense.”': 20}]
# 1393 : [{'Christmas': 20}]
# 1394 : [{'intense.”': 20}]
# 1401 : [{'tongue.”': 10}]
# 1405 : [{'‘fine': 10}]
# 1410 : [{'plasticity—well': 10}]
# 1413 : [{'Albemarle’s': 10}]
# 1415 : [{'significance—that’s': 10}]
# 1423 : [{'butlerish': 10}]
# 1427 : [{'masters.”': 10}]
# 1431 : [{'masters—he': 10}]
# 1436 : [{'exacerbatingly': 10}]
# 1439 : [{'years.”': 10}]
# 1447 : [{'through.”': 10}]
# 1451 : [{'Quite.”': 20}]
# 1456 : [{'Leonardo': 20}, {'Boscovitch': 10}]
# 1457 : [{'Handel': 10}]
# 1459 : [{'example.”': 20}]
# 1466 : [{'of—how': 10}, {'it—dissipating': 10}]
# 1472 : [{'experience.”': 10}]
# 1480 : [{'things—always': 10}]
# 1488 : [{'composition”': 10}, {'‘swirling': 10}, {'composition’—mentally': 10}]
# 1490 : [{'more——”': 10}]
# 1501 : [{'temp——”': 10}]
# 1503 : [{'magnificent.”': 10}]
# 1510 : [{'world.”': 20}]
# 1516 : [{'Psh': 10}, {'psh': 10}]
# 1524 : [{'passage.”': 10}]
# 1525 : [{'a——”': 20}]
# 1527 : [{'red—“what': 10}, {'composition.”': 10}]
# 1536 : [{'face—a': 10}]
# 1538 : [{'once—“and': 10}]
# 1545 : [{'it—a': 10}]
# 1549 : [{'terrific.”': 10}]
# 1569 : [{'‘they’': 10}]
# 1577 : [{'grocer’s': 10}]
# 1586 : [{'Friday.”': 10}]
# 1593 : [{'short.”': 10}]
# 1601 : [{'IV': 10}]
# 1604 : [{'trying—and': 10}]
# 1606 : [{'inspiration—a': 10}]
# 1618 : [{'Soho': 20}]
# 1619 : [{'‘artistic': 10}]
# 1620 : [{'money’s': 10}]
# 1623 : [{'Conquistador”—that': 10}]
# 1627 : [{'Tenochtitlan': 10}, {'Iztapalapan': 10}, {'symbolized—well': 10}]
# 1633 : [{'valley’s': 20}]
# 1638 : [{'dream.”': 10}]
# 1640 : [{'‘dream': 20}]
# 1641 : [{'‘dream': 20}]
# 1650 : [{'‘dream.’': 10}]
# 1656 : [{'can’t.”': 20}]
# 1669 : [{'refinedly': 10}]
# 1675 : [{'theme—the': 10}]
# 1681 : [{'Sunt': 10}, {'lacrymæ': 10}]
# 1682 : [{'rerum': 10}, {'mutamur': 10}, {'illis': 10}]
# 1684 : [{'Quot': 10}, {'disputandum': 10}, {'est': 10}]
# 1685 : [{'Beaune': 10}, {'Supérieure': 10}]
# 1689 : [{'Ça': 20}, {'se': 20}, {'cher': 20}]
# 1690 : [{'s’explique': 10}, {'Satan': 10}]
# 1691 : [{'Mercaptan—wherever': 10}]
# 1697 : [{'Rostand': 20}]
# 1698 : [{'Rève': 10}, {'—ah': 10}]
# 1712 : [{'cow’s': 10}]
# 1713 : [{'quiet.”': 10}]
# 1716 : [{'daren’t': 20}]
# 1718 : [{'word’s': 10}]
# 1719 : [{'Titan’s': 10}]
# 1721 : [{'Ideals—they’re': 10}]
# 1723 : [{'morality.”': 10}]
# 1731 : [{'bull’s': 10}]
# 1732 : [{'robin’s': 10}]
# 1735 : [{'Crebillon': 10}, {'needn’t': 20}, {'Russians': 20}]
# 1736 : [{'Dostoievskys.”': 10}]
# 1737 : [{'naturel': 20}, {'——”': 20}]
# 1738 : [{'pue': 20}]
# 1739 : [{'Wells—': 10}, {'pue': 20}, {'assez': 10}]
# 1745 : [{'comfort—that’s': 20}, {'for.”': 10}]
# 1751 : [{'pairs.”': 10}]
# 1753 : [{'Wellsian': 10}]
# 1754 : [{'They’d': 10}]
# 1757 : [{'Tolstoy': 10}]
# 1760 : [{'Russian.”': 10}]
# 1765 : [{'mind—“Alberti': 10}]
# 1768 : [{'Borromini': 10}, {'baroque.”': 10}]
# 1770 : [{'Blake': 20}]
# 1774 : [{'boudoir.”': 10}]
# 1777 : [{'me—you': 10}]
# 1779 : [{'art’s': 20}]
# 1782 : [{'great.”': 10}]
# 1790 : [{'myself.”': 20}]
# 1801 : [{'‘dreams’': 10}, {'inadmissible.”': 10}]
# 1805 : [{'Rostand': 20}]
# 1807 : [{'Freud.”': 10}]
# 1813 : [{'straightforwardly': 10}]
# 1814 : [{'compromises.”': 10}]
# 1824 : [{'sta': 10}, {'Sua': 10}, {'Terribiltà': 10}]
# 1832 : [{'beard”—he': 10}, {'fan—“why': 10}]
# 1834 : [{'Russianism': 10}]
# 1839 : [{'Christlike': 10}]
# 1845 : [{'heaven’s': 10}]
# 1846 : [{'mother’s': 20}, {'womb.”': 10}]
# 1849 : [{'hideous.”': 10}]
# 1854 : [{'‘Beaver': 10}]
# 1857 : [{'relations.”': 10}]
# 1866 : [{'‘beaver’': 10}]
# 1872 : [{'physiologist.”': 10}]
# 1887 : [{'—even': 10}]
# 1897 : [{'all—not': 10}]
# 1900 : [{'Ça': 20}, {'marche—les': 10}, {'Hein': 10}]
# 1904 : [{'newspapers.”': 10}]
# 1917 : [{'and——”': 10}]
# 1920 : [{'will——”': 10}]
# 1923 : [{'runions': 10}]
# 1924 : [{'them—': 10}, {'sautés': 20}, {'Sautés': 10}, {'words.”': 20}]
# 1930 : [{'unbelievers—confronted': 10}]
# 1931 : [{'croyants': 10}, {'pratiquants': 10}]
# 1932 : [{'Samael': 10}]
# 1936 : [{'labiating': 10}, {'‘civilized’': 10}]
# 1937 : [{'’s': 10}]
# 1943 : [{'boyau': 20}]
# 1944 : [{'Voltaire': 10}, {'‘His': 10}]
# 1945 : [{'‘were': 10}]
# 1946 : [{'calf’s': 10}, {'foot.’': 10}]
# 1947 : [{'Mustn’t': 10}]
# 1948 : [{'rognons': 20}, {'sautés': 20}]
# 1952 : [{'mortually': 10}, {'’ope': 10}]
# 1953 : [{'Mortually': 10}, {'’Ardy': 10}]
# 1957 : [{'frogs—crucified': 10}]
# 1958 : [{'Christs—I': 10}]
# 1960 : [{'‘Please': 10}]
# 1962 : [{'Yale': 20}]
# 1964 : [{'wanted—to': 10}]
# 1965 : [{'fœtus': 10}]
# 1967 : [{'Adam': 10}, {'boyau': 20}]
# 1980 : [{'Voltaire’s': 10}]
# 1986 : [{'miraculous—it’s': 10}, {'word—such': 10}]
# 1989 : [{'pair.”': 10}]
# 1993 : [{'Yale': 20}, {'Sephiroth': 10}]
# 1994 : [{'trollop.”': 10}]
# 2003 : [{'compagne': 10}, {'mes': 20}, {'nuits': 10}, {'mes': 20}, {'jours': 20}, {'plutôt': 10}]
# 2004 : [{'Qui': 10}, {'comprend': 10}, {'français': 10}, {'déteste': 10}]
# 2005 : [{'avec': 10}, {'une': 10}, {'égale': 10}, {'mienne': 10}, {'mangera': 10}, {'foi': 10}, {'rognons': 20}]
# 2006 : [{'faire': 10}, {'honneur': 10}]
# 2012 : [{'Augustus': 10}]
# 2019 : [{'Metternich': 20}, {'Pio': 20}]
# 2020 : [{'Nono.”': 10}]
# 2026 : [{'Boehme': 10}, {'Michelangelo—what': 10}]
# 2031 : [{'architect.”': 10}]
# 2033 : [{'Fi': 10}, {'donc': 10}, {'San': 20}, {'Carlo': 10}, {'alle': 10}, {'Quatro': 10}, {'Fontane——”': 10}]
# 2036 : [{'reality.”': 10}]
# 2039 : [{'Zoe’s': 10}, {'callipygous.”': 10}]
# 2047 : [{'universe.”': 10}]
# 2049 : [{'barbaridad': 20}]
# 2050 : [{'barbaridad': 20}, {'Castilian': 10}]
# 2051 : [{'meaningless.”': 10}]
# 2062 : [{'reproduction.”': 10}]
# 2066 : [{'But——”': 10}]
# 2076 : [{'‘Bekkos': 10}]
# 2077 : [{'Herodotus': 10}]
# 2078 : [{'Savage.’': 10}]
# 2083 : [{'Shouldn’t': 10}]
# 2085 : [{'I——”': 20}]
# 2106 : [{'empest': 10}]
# 2107 : [{'air.”': 20}]
# 2112 : [{'night.”': 10}]
# 2113 : [{'‘Barcarolle’': 10}, {'Hoffmann': 10}]
# 2114 : [{'Liebe': 10}, {'Nacht': 20}, {'schöne': 10}, {'Nacht': 20}, {'stille': 10}, {'mein': 10}, {'tum': 20}]
# 2115 : [{'tum': 20}, {'Offenbach': 10}]
# 2117 : [{'Tiddy': 10}]
# 2127 : [{'doctor.”': 10}]
# 2136 : [{'empested': 10}]
# 2146 : [{'centipedes.”': 10}]
# 2151 : [{'ever.”': 20}]
# 2158 : [{'e’s': 10}]
# 2164 : [{'Hyde': 10}]
# 2166 : [{'chauffeurs’': 10}, {'workmen’s': 10}]
# 2172 : [{'Viveash.”': 20}]
# 2191 : [{'me”—he': 10}]
# 2192 : [{'Zoe—“a': 10}]
# 2193 : [{'priapagogue': 10}]
# 2195 : [{'kabbalistically': 10}]
# 2196 : [{'service.”': 20}]
# 2209 : [{'breakingly': 10}]
# 2218 : [{'hand—for': 10}]
# 2219 : [{'egg—on': 10}]
# 2225 : [{'remembered.”': 10}]
# 2230 : [{'espérer': 10}]
# 2235 : [{'cat’s': 10}]
# 2238 : [{'Bellissima': 10}]
# 2241 : [{'Haven’t': 10}]
# 2248 : [{'Hampton': 20}]
# 2252 : [{'Cythera': 10}, {'Capri': 10}, {'Je': 10}, {'demande': 10}]
# 2254 : [{'middle.”': 10}]
# 2259 : [{'collector’s': 10}]
# 2264 : [{'up—rather': 10}]
# 2271 : [{'Bruin’s': 20}]
# 2272 : [{'be.”': 20}]
# 2276 : [{'Hampton': 20}]
# 2278 : [{'workmen—well': 10}]
# 2302 : [{'while.”': 10}]
# 2307 : [{'Italy': 20}, {'Trematodes—all': 10}]
# 2309 : [{'leisure.”': 10}]
# 2324 : [{'mori': 20}, {'anatomy.”': 10}]
# 2333 : [{'vivere': 10}, {'Vivamus': 20}, {'mea': 20}]
# 2334 : [{'Lesbia': 20}, {'atque': 10}, {'amemus': 10}]
# 2344 : [{'We’d': 20}]
# 2357 : [{'Mayn’t': 10}]
# 2362 : [{'Can’t': 20}, {'sick.”': 10}]
# 2364 : [{'Quelle': 20}, {'âme': 10}]
# 2365 : [{'say.”': 20}]
# 2373 : [{'‘Rot': 10}]
# 2374 : [{'Classes.’': 10}]
# 2375 : [{'song.”': 10}]
# 2385 : [{'intolerable.”': 10}]
# 2390 : [{'arms.”': 10}]
# 2393 : [{'moment.”': 10}]
# 2398 : [{'Bruin’s': 20}]
# 2401 : [{'cartin’': 10}, {'’Ad': 20}]
# 2402 : [{'nold': 10}]
# 2403 : [{'’eavy': 10}]
# 2404 : [{'India': 20}]
# 2406 : [{'even—you': 10}, {'modesty—nor': 10}]
# 2411 : [{'delighteth': 10}]
# 2415 : [{'does.”': 10}]
# 2418 : [{'child.”': 20}]
# 2427 : [{'’Ad': 20}, {'Florrie': 10}]
# 2443 : [{'goin’': 20}, {'Ludgate': 20}, {'’Ill': 10}]
# 2444 : [{'Clerkenwell': 10}, {'leadin’': 10}, {'’ill—Jerry’s': 10}]
# 2449 : [{'domestically.”': 10}]
# 2451 : [{'Quelle': 20}, {'horreur': 10}, {'Quinze': 10}, {'Abbé': 10}]
# 2458 : [{'‘’Ow': 10}]
# 2459 : [{'‘It': 20}, {'ain’t': 10}, {'drawr': 10}]
# 2460 : [{'‘No': 10}, {'‘None': 10}, {'answerin’': 10}]
# 2461 : [{'‘Take': 10}, {'once.’”': 10}]
# 2474 : [{'moments.”': 10}]
# 2476 : [{'magistrate’s': 10}]
# 2484 : [{'‘Limping': 10}]
# 2485 : [{'‘It': 20}]
# 2486 : [{'’as': 20}]
# 2487 : [{'old.’': 10}, {'goin’': 20}]
# 2490 : [{'^2': 20}, {'^2': 20}]
# 2494 : [{'peculiarities—after': 10}]
# 2500 : [{'’E’s': 20}, {'work.’': 10}]
# 2502 : [{'’Ow': 10}]
# 2509 : [{'‘I’m': 10}]
# 2510 : [{'law.’': 10}, {'‘Seems': 10}, {'‘What': 20}]
# 2518 : [{'‘What': 20}, {'Croolty': 10}]
# 2519 : [{'says.”': 10}]
# 2527 : [{'’aving': 10}, {'workin’': 10}]
# 2528 : [{'’eard': 10}]
# 2529 : [{'walkin’': 10}]
# 2530 : [{'there.”': 20}]
# 2534 : [{'‘’Opeless': 10}, {'‘quite': 10}, {'’opeless': 10}]
# 2535 : [{'vacancies.’': 10}]
# 2538 : [{'’arder': 10}, {'comes.”': 10}]
# 2543 : [{'awful.”': 10}]
# 2544 : [{'Nineveh': 10}]
# 2549 : [{'child.”': 20}]
# 2552 : [{'gravidy': 10}]
# 2553 : [{'Newstein': 10}]
# 2554 : [{'o’er': 10}]
# 2555 : [{'earth.”': 10}]
# 2568 : [{'barocco': 10}]
# 2591 : [{'Paddington': 20}]
# 2615 : [{'work—hours': 10}]
# 2625 : [{'dogs.”': 10}]
# 2627 : [{'of.”': 10}]
# 2629 : [{'fuss.”': 10}]
# 2637 : [{'board—they': 10}]
# 2649 : [{'terrible.”': 10}]
# 2651 : [{'Cursitor': 10}]
# 2666 : [{'park’s': 10}]
# 2680 : [{'Thursday.”': 10}]
# 2685 : [{'Totally.”': 10}]
# 2689 : [{'jealousy.”': 10}]
# 2694 : [{'implored—only': 10}]
# 2698 : [{'beauty—of': 10}]
# 2703 : [{'uncomfortable.”': 10}]
# 2704 : [{'two’s': 10}]
# 2712 : [{'French.”': 10}]
# 2714 : [{'yes.”': 10}]
# 2717 : [{'‘Puisque': 10}, {'sommes': 10}, {'là': 10}, {'je': 20}, {'dois': 10}]
# 2718 : [{'Vous': 10}, {'avertir': 10}, {'honte': 10}]
# 2719 : [{'Que': 10}, {'je': 20}, {'n’égale': 10}]
# 2720 : [{'Casanovesque': 10}, {'Sixfois.’': 10}]
# 2722 : [{'gross.”': 10}]
# 2731 : [{'VI': 10}]
# 2734 : [{'Whitefield': 10}]
# 2735 : [{'‘heavenly': 10}]
# 2737 : [{'brick—and': 10}]
# 2740 : [{'prisons—and': 10}]
# 2768 : [{'gentlewomen—you': 10}]
# 2769 : [{'to.”': 20}]
# 2776 : [{'dress—white': 10}]
# 2777 : [{'it—blowing': 10}]
# 2783 : [{'doors—for': 10}]
# 2786 : [{'Prometheus': 20}]
# 2795 : [{'Hamelin': 10}]
# 2818 : [{'rate.”': 10}]
# 2830 : [{'bit.”': 10}]
# 2833 : [{'mob’s': 10}]
# 2834 : [{'‘Oh': 10}]
# 2836 : [{'stones.”': 20}]
# 2838 : [{'stones.”': 20}]
# 2849 : [{'again—she': 10}]
# 2868 : [{'Prometheus': 20}]
# 2869 : [{'tigresses.”': 10}]
# 2871 : [{'slowly.”': 10}]
# 2891 : [{'laugh.”': 10}]
# 2903 : [{'Work—it’s': 10}, {'Tigress.’”': 10}]
# 2909 : [{'Disease’': 10}]
# 2916 : [{'monkeyishly': 10}]
# 2922 : [{'Disease’—she': 10}]
# 2926 : [{'Œdipus': 10}]
# 2932 : [{'arm’s': 10}]
# 2948 : [{'wind.”': 20}, {'violence—what': 10}]
# 2967 : [{'Atlantic': 20}, {'gale.”': 10}]
# 2976 : [{'Padua': 10}, {'Cinzano': 20}, {'Campari—illustrious': 10}]
# 2977 : [{'Giotto': 10}, {'Mantegna': 20}]
# 2985 : [{'spirit—rushing': 10}, {'own.”': 20}]
# 2989 : [{'valley’s': 20}]
# 2996 : [{'music——”': 10}]
# 2997 : [{'Scriabin': 10}]
# 3000 : [{'significance.”': 10}]
# 3002 : [{'too.”': 10}]
# 3004 : [{'‘Like': 10}, {'fleeing.’': 10}]
# 3006 : [{'four—by': 10}, {'wind.”': 20}]
# 3009 : [{'life—that’s': 10}]
# 3012 : [{'art’s': 20}]
# 3013 : [{'æsthetic': 10}]
# 3015 : [{'another—that’s': 10}]
# 3021 : [{'Gogh': 10}]
# 3022 : [{'lover’s': 10}]
# 3023 : [{'Mantegna': 20}]
# 3029 : [{'Cinzano': 20}]
# 3032 : [{'Canadian': 10}]
# 3033 : [{'tripe.”': 10}]
# 3038 : [{'bad—she': 10}]
# 3046 : [{'needn’t': 20}]
# 3054 : [{'last—he': 10}]
# 3055 : [{'sitting.”': 10}]
# 3058 : [{'waste.”': 10}]
# 3061 : [{'Lypiatt—it’s': 10}]
# 3064 : [{'depressing.”': 10}]
# 3066 : [{'model’s': 10}]
# 3070 : [{'passion—were': 10}]
# 3071 : [{'That’ll': 20}]
# 3093 : [{'unjuster': 10}]
# 3105 : [{'wait—a': 10}]
# 3106 : [{'time—sometimes': 10}, {'Blake': 20}]
# 3122 : [{'unintimate': 10}]
# 3126 : [{'there—so': 10}]
# 3129 : [{'understands.”': 10}]
# 3135 : [{'Myra—you': 10}]
# 3136 : [{'kind.”': 20}]
# 3140 : [{'tracks—that': 10}]
# 3141 : [{'There’d': 10}]
# 3166 : [{'die.”': 10}]
# 3188 : [{'Artist”—he': 10}]
# 3190 : [{'mantle—“an': 10}]
# 3196 : [{'exhibition—ah': 10}]
# 3211 : [{'VII': 10}]
# 3228 : [{'—the': 20}]
# 3229 : [{'Grubb’s': 10}]
# 3231 : [{'Clew’s': 10}]
# 3234 : [{'indiscriminately': 10}]
# 3235 : [{'Memling': 10}]
# 3236 : [{'Raphael': 10}, {'Grünewald': 10}, {'Holman': 10}]
# 3237 : [{'Manet': 10}, {'Romney': 10}, {'Tintoretto': 10}]
# 3242 : [{'Matisse’s': 10}, {'kunstforscher': 10}]
# 3245 : [{'Piazetta': 10}]
# 3249 : [{'Grecos': 10}]
# 3250 : [{'Bassano': 10}]
# 3252 : [{'Duccio': 10}]
# 3254 : [{'Illinois': 10}]
# 3255 : [{'seen.”': 10}, {'Simone': 10}]
# 3258 : [{'America.”': 10}]
# 3259 : [{'Petersfield': 10}]
# 3260 : [{'Giorgione': 10}]
# 3264 : [{'‘Genius': 10}]
# 3265 : [{'‘is': 10}]
# 3269 : [{'cetera': 20}, {'cetera': 20}]
# 3272 : [{'flows.’': 10}]
# 3273 : [{'indeed.”': 20}]
# 3286 : [{'Hodler': 10}]
# 3288 : [{'Calvinist': 10}]
# 3293 : [{'propitiatingly': 10}]
# 3294 : [{'Mallard’s': 20}]
# 3300 : [{'Greco’s': 10}, {'exemplifies.”': 10}]
# 3314 : [{'‘O': 10}]
# 3317 : [{'field—he': 10}]
# 3319 : [{'will.’': 10}]
# 3323 : [{'commonplace.”': 10}]
# 3326 : [{'diagonal—it’s': 10}, {'death.”': 10}]
# 3327 : [{'catalogue—a': 10}]
# 3328 : [{'pirate’s': 10}, {'Mallard’s': 20}]
# 3337 : [{'a—h’m—declaration': 10}, {'faith.”': 10}]
# 3340 : [{'grateful.”': 10}]
# 3345 : [{'mauvais': 10}]
# 3353 : [{'mottoes.”': 10}]
# 3354 : [{'‘Look': 10}, {'itself.’': 10}]
# 3355 : [{'‘God': 10}]
# 3356 : [{'morals’—only': 10}]
# 3358 : [{'ever.”': 20}]
# 3361 : [{'‘A': 10}]
# 3362 : [{'significance.’”': 10}]
# 3366 : [{'‘Those': 10}]
# 3367 : [{'hydrogen.’”': 10}]
# 3370 : [{'c’est': 10}, {'l’homme': 10}, {'Argal—inexorable': 10}]
# 3371 : [{'conclusion—Lypiatt': 10}]
# 3372 : [{'Carracis': 10}, {'muscles.”': 10}]
# 3374 : [{'Sampson': 10}, {'Delilah': 10}]
# 3383 : [{'‘An': 10}]
# 3388 : [{'godhead.’”': 10}]
# 3395 : [{'‘Aerial': 20}, {'Alps’”': 10}]
# 3397 : [{'‘Aerial': 20}]
# 3398 : [{'Junonian': 10}]
# 3399 : [{'wind’s': 10}, {'.’”': 10}]
# 3403 : [{'‘Woman': 10}]
# 3406 : [{'‘For': 10}, {'universe.’”': 10}]
# 3409 : [{'know—Cinzano': 10}]
# 3411 : [{'Casimir.”': 20}]
# 3414 : [{'hat.”': 10}]
# 3420 : [{'top—it': 10}, {'dramatic.”': 10}]
# 3426 : [{'indeed.”': 20}]
# 3429 : [{'ces': 20}, {'ces': 20}]
# 3430 : [{'Pasiphaes': 10}, {'Ledas': 10}]
# 3431 : [{'believe.”': 20}]
# 3442 : [{'VIII': 10}]
# 3465 : [{'‘nice.’”': 10}]
# 3473 : [{'disagree.”': 10}]
# 3476 : [{'African': 20}]
# 3478 : [{'pelican’s': 10}, {'beak.”': 10}]
# 3482 : [{'African': 20}, {'negroes.”': 10}]
# 3490 : [{'rigueur': 20}]
# 3493 : [{'Byronic': 10}]
# 3495 : [{'nowadays.”': 10}]
# 3502 : [{'rigueur': 20}]
# 3506 : [{'politician’s': 10}, {'normal.”': 10}]
# 3511 : [{'distangay': 10}]
# 3512 : [{'mean.”': 10}]
# 3521 : [{'badge—at': 10}, {'occasions—for': 10}]
# 3522 : [{'Councillors’': 10}]
# 3523 : [{'’E’s': 20}]
# 3524 : [{'’is': 20}, {'’apazard': 10}]
# 3525 : [{'’apazard.”': 10}]
# 3530 : [{'’uge': 10}]
# 3532 : [{'Lloyd': 20}, {'’ats': 10}, {'Winston': 10}, {'Churchill': 10}]
# 3533 : [{'Mussolini': 10}]
# 3535 : [{'Clemenceau': 10}, {'Tirpitz': 10}]
# 3537 : [{'tattooings': 10}]
# 3538 : [{'urims': 10}, {'thummims': 10}]
# 3540 : [{'’oo': 20}]
# 3551 : [{'d’oil': 10}]
# 3552 : [{'’appens': 10}]
# 3555 : [{'’and': 10}]
# 3566 : [{'’as': 20}, {'specimens.”': 10}]
# 3573 : [{'’is': 20}]
# 3574 : [{'Pears’': 10}]
# 3575 : [{'Lloyd': 20}]
# 3584 : [{'good.”': 10}]
# 3588 : [{'leader—do': 10}]
# 3595 : [{'dyingly': 10}]
# 3600 : [{'feeling.”': 10}]
# 3605 : [{'’erd.”': 10}]
# 3607 : [{'perhaps.”': 10}]
# 3613 : [{'herds—by': 10}]
# 3619 : [{'Bojanus—he': 10}]
# 3624 : [{'Leicester': 10}]
# 3628 : [{'symbol’s': 10}]
# 3654 : [{'disproportionately': 10}]
# 3664 : [{'cœnobites': 10}]
# 3666 : [{'beard—“put': 10}]
# 3668 : [{'up—ha': 10}]
# 3670 : [{'moustache—that': 10}, {'enough—which': 10}]
# 3675 : [{'Maurice': 10}, {'Barrès': 10}]
# 3680 : [{'marvellously': 20}]
# 3685 : [{'Zadig’s': 10}]
# 3693 : [{'Zadig': 10}]
# 3700 : [{'constatation': 10}]
# 3708 : [{'coat—a': 10}]
# 3725 : [{'pass—for': 10}]
# 3732 : [{'sky’s': 10}]
# 3737 : [{'Beaver”': 10}]
# 3739 : [{'favourable': 20}]
# 3742 : [{'tobacconist’s': 20}]
# 3743 : [{'Cuban': 10}]
# 3746 : [{'intended—how': 10}]
# 3747 : [{'—to': 10}]
# 3752 : [{'Whiteley’s': 10}]
# 3760 : [{'tubular—flexible': 10}]
# 3769 : [{'tubularity': 10}]
# 3778 : [{'another—a': 10}]
# 3780 : [{'another—attraction': 10}]
# 3796 : [{'gentleman’s': 20}, {'hosiery—she': 10}]
# 3799 : [{'neat’s': 10}]
# 3800 : [{'serpent’s': 10}]
# 3802 : [{'jeweller’s': 10}]
# 3803 : [{'antiquarian’s': 10}, {'milliner’s': 10}]
# 3810 : [{'breaking—with': 10}]
# 3812 : [{'—a': 10}]
# 3817 : [{'Chippendale': 10}]
# 3820 : [{'Bayswater': 20}]
# 3823 : [{'Douro': 10}]
# 3827 : [{'antiquary’s': 10}]
# 3828 : [{'Heppelwhite': 20}]
# 3834 : [{'François': 10}]
# 3836 : [{'stranger’s': 20}]
# 3839 : [{'Heppelwhite': 20}]
# 3840 : [{'stranger’s': 20}]
# 3844 : [{'may.”': 10}]
# 3850 : [{'N—n—nothing”—it': 10}]
# 3854 : [{'it—the': 10}]
# 3856 : [{'conversation.”': 10}]
# 3866 : [{'sin.”': 10}]
# 3872 : [{'pr—ray': 10}]
# 3884 : [{'‘Ye': 10}, {'Olde': 10}, {'Farme': 10}, {'House.’': 10}]
# 3888 : [{'v—vulgar.”': 10}]
# 3890 : [{'artistic.”': 10}]
# 3895 : [{'was—with': 10}]
# 3898 : [{'Aggie’s': 10}]
# 3899 : [{'now—no': 10}]
# 3903 : [{'s—sorry': 10}]
# 3908 : [{'af—fraid.”': 10}]
# 3915 : [{'Bayswater': 20}]
# 3945 : [{'thing—one': 10}]
# 3965 : [{'party—oh': 10}]
# 3969 : [{'passion—how': 10}]
# 3982 : [{'Tiresias': 10}]
# 3983 : [{'woman.”': 10}]
# 3994 : [{'Maida': 20}]
# 3995 : [{'Gardens—perhaps': 10}]
# 3997 : [{'dr—dreadful': 10}, {'maisonnette': 20}]
# 4016 : [{'maisonnette': 20}, {'splendid—six': 10}]
# 4018 : [{'furniture—decidedly': 10}]
# 4019 : [{'cretonnes—brightly': 10}, {'‘modern': 10}, {'‘futurist.’': 10}]
# 4028 : [{'Riviera.”': 10}]
# 4031 : [{'Riviera—that': 10}]
# 4041 : [{'servants”—the': 10}]
# 4042 : [{'exaggeration—“are': 10}, {'out.”': 20}]
# 4072 : [{'rings—there': 10}]
# 4077 : [{'artistic—only': 10}]
# 4082 : [{'rate—which': 10}, {'thing—very': 10}]
# 4085 : [{'Catherine': 20}]
# 4086 : [{'Russia': 10}]
# 4087 : [{'butcher’s': 20}]
# 4088 : [{'life—it': 10}]
# 4089 : [{'lived—life—to': 10}]
# 4099 : [{'N—nothing': 20}]
# 4101 : [{'N—nothing': 20}]
# 4102 : [{'n—nothing': 10}]
# 4104 : [{'l—least': 20}, {'importance.”': 20}]
# 4108 : [{'l—least': 20}]
# 4120 : [{'can’t.”': 20}]
# 4123 : [{'couldn’t.”': 10}]
# 4130 : [{'duty.”': 10}]
# 4132 : [{'uniquely.”': 10}]
# 4141 : [{'Catherine’s': 10}]
# 4153 : [{'beaver’s': 10}]
# 4160 : [{'Jupiter': 20}]
# 4163 : [{'her—suspecting': 10}]
# 4166 : [{'that—a': 10}]
# 4172 : [{'Man’s': 10}]
# 4174 : [{'Raphael’s': 10}, {'‘Transfiguration’—better': 10}]
# 4178 : [{'nice.”': 10}]
# 4188 : [{'men’s': 10}]
# 4189 : [{'own.”': 20}]
# 4194 : [{'by—who': 10}, {'forget.”': 20}]
# 4196 : [{'Domenichino’s': 10}, {'‘St': 10}, {'Jerome’': 10}]
# 4197 : [{'Poussin’s': 10}]
# 4202 : [{'don’t.”': 10}]
# 4211 : [{'wondering—oh': 10}, {'years—every': 10}]
# 4222 : [{'Persian': 10}]
# 4231 : [{'saint’s': 20}]
# 4239 : [{'picture’s': 10}]
# 4246 : [{'obscure.”': 10}]
# 4251 : [{'particular.”': 10}]
# 4274 : [{'lady’s': 10}]
# 4289 : [{'‘Rosie’”': 10}]
# 4300 : [{'James—but': 10}]
# 4307 : [{'Shear——': 10}]
# 4308 : [{'Lord.”': 20}]
# 4326 : [{'saying—he': 10}]
# 4338 : [{'poacher’s': 10}]
# 4342 : [{'her.”': 10}]
# 4351 : [{'sight.”': 10}]
# 4354 : [{'remarkable.”': 10}]
# 4385 : [{'cup.”': 10}]
# 4413 : [{'longue': 10}, {'Récamier': 10}]
# 4415 : [{'snake.”': 10}]
# 4425 : [{'hedonist.”': 10}]
# 4427 : [{'pleasure.”': 10}]
# 4429 : [{'‘conscientious': 10}, {'hedonist’—ah': 10}]
# 4457 : [{'soup’s': 10}, {'cold.”': 10}]
# 4474 : [{'Jim': 20}]
# 4479 : [{'wonderful.”': 10}]
# 4481 : [{'remember.”': 10}]
# 4483 : [{'smiled—a': 10}]
# 4506 : [{'bird’s': 20}, {'bird’s': 20}]
# 4510 : [{'goods—or': 10}]
# 4517 : [{'knowledge—they': 10}]
# 4526 : [{'knows—knows': 10}]
# 4531 : [{'Picasso': 20}, {'Derain': 20}]
# 4535 : [{'Spaniard’s': 10}]
# 4536 : [{'Bacosso—why': 10}]
# 4563 : [{'work.”': 20}]
# 4573 : [{'shan’t': 20}]
# 4582 : [{'it—in': 10}]
# 4592 : [{'mori': 20}]
# 4598 : [{'floor—arriving': 10}]
# 4599 : [{'bruiseless': 10}, {'unjarred': 10}]
# 4603 : [{'favourably': 10}]
# 4605 : [{'‘maximum': 10}]
# 4606 : [{'bulge.’': 10}]
# 4616 : [{'importance.”': 20}]
# 4620 : [{'sci—en—tifically.”': 10}]
# 4630 : [{'sex.”': 10}]
# 4634 : [{'peg.”': 10}]
# 4638 : [{'no.”': 10}]
# 4639 : [{'Viennese': 10}]
# 4642 : [{'herd.”': 10}]
# 4644 : [{'True.”': 10}]
# 4646 : [{'Professor’s': 10}]
# 4656 : [{'different—at': 10}]
# 4658 : [{'scientifically.”': 10}]
# 4662 : [{'financier’s': 10}]
# 4666 : [{'Boldero.”': 10}]
# 4673 : [{'suggestions.”': 10}]
# 4681 : [{'comfort—that’s': 20}]
# 4685 : [{'instincts.”': 10}]
# 4691 : [{'Mighty.’': 10}]
# 4692 : [{'world.’': 10}]
# 4694 : [{'they’ve': 20}]
# 4699 : [{'public—not': 10}, {'tradesmanlike': 10}]
# 4702 : [{'superiors—because': 10}]
# 4704 : [{'equal—all': 10}]
# 4705 : [{'equals.”': 10}]
# 4712 : [{'ennobling—which': 10}, {'cretinizing': 10}]
# 4720 : [{'Gumbril—that’s': 10}]
# 4721 : [{'nowadays—at': 10}]
# 4724 : [{'trousers.”': 10}]
# 4733 : [{'ganglia—if': 10}]
# 4742 : [{'cure—if': 10}]
# 4743 : [{'life—is': 10}]
# 4754 : [{'‘ganglia.’”': 10}]
# 4756 : [{'Anglia': 10}]
# 4763 : [{'appears—can': 10}]
# 4767 : [{'They’ll': 20}]
# 4772 : [{'Egyptology': 10}]
# 4776 : [{'Egypt': 10}]
# 4782 : [{'Metchnikoff’s': 10}]
# 4798 : [{'can.”': 10}]
# 4807 : [{'Humanities.”': 10}]
# 4817 : [{'Thing—socially': 10}]
# 4820 : [{'Chaplin’s': 10}]
# 4822 : [{'up—white': 10}]
# 4830 : [{'tailor’s': 20}]
# 4831 : [{'‘Good': 10}, {'good.’': 10}]
# 4839 : [{'committer': 10}]
# 4843 : [{'poise—incisive': 10}]
# 4844 : [{'‘Gumbril’s': 10}, {'men.’': 20}]
# 4848 : [{'astigmat': 10}]
# 4858 : [{'fiancée': 10}]
# 4859 : [{'air.”': 20}]
# 4870 : [{'‘English': 10}]
# 4871 : [{'men.’': 20}]
# 4895 : [{'things.”': 20}]
# 4899 : [{'‘One': 10}]
# 4900 : [{'trousers.’': 10}]
# 4901 : [{'uninteresting.”': 10}]
# 4907 : [{'course.”': 20}]
# 4910 : [{'name’s': 10}]
# 4913 : [{'Lydgate.”': 10}]
# 4915 : [{'Lypiatt.”': 10}]
# 4917 : [{'Lypgate': 10}, {'course.”': 20}]
# 4931 : [{'person’s': 10}, {'view—poor': 10}]
# 4937 : [{'enthusiastically': 20}]
# 4943 : [{'naked—naked': 10}]
# 4944 : [{'whiteness—how': 10}]
# 4946 : [{'range—if': 10}]
# 4948 : [{'Do.”': 10}]
# 4952 : [{'week—and': 10}]
# 4963 : [{'leprechaun—there': 10}]
# 4966 : [{'MR': 20}, {'BOLDERO': 10}]
# 4973 : [{'satisfactorily.—Believe': 10}]
# 4975 : [{'THEODORE': 10}, {'GUMBRIL': 10}, {'JR.”': 10}]
# 4978 : [{'Rabelaisianly': 10}]
# 4986 : [{'Won’t': 10}]
# 4998 : [{'shan’t': 20}]
# 5031 : [{'two—sunk': 10}]
# 5037 : [{'‘England': 10}]
# 5038 : [{'words.”': 20}]
# 5041 : [{'Englishmen': 10}, {'Manufacturer’s': 10}]
# 5043 : [{'responsibilities': 20}]
# 5044 : [{'responsibilities': 20}]
# 5056 : [{'reading—one': 10}]
# 5061 : [{'servant’s': 20}]
# 5065 : [{'Jewish': 10}]
# 5072 : [{'Atlantic': 20}]
# 5081 : [{'down.”': 10}]
# 5094 : [{'Man—to': 10}]
# 5095 : [{'Anon—the': 10}]
# 5096 : [{'painter—Ignoto': 10}]
# 5100 : [{'Shearwater—but': 10}]
# 5122 : [{'people.”': 10}]
# 5126 : [{'Quite.”': 20}]
# 5129 : [{'People’s': 20}]
# 5130 : [{'People’s': 20}]
# 5139 : [{'love.”': 20}]
# 5149 : [{'before.”': 10}]
# 5161 : [{'like.”': 10}]
# 5167 : [{'else—their': 10}]
# 5171 : [{'yourself.”': 10}]
# 5181 : [{'passion—he': 10}]
# 5183 : [{'Women—only': 10}]
# 5188 : [{'shameful.”': 20}]
# 5196 : [{'come.”': 10}]
# 5201 : [{'Cæsar': 10}, {'Cæsar’s': 10}]
# 5203 : [{'arrangement.”': 10}]
# 5205 : [{'proportion.”': 20}]
# 5207 : [{'Who’s': 20}]
# 5214 : [{'said—“I': 10}]
# 5220 : [{'Mozart—how': 10}]
# 5222 : [{'There’ll': 10}]
# 5224 : [{'Brobdingnagian': 10}]
# 5225 : [{'time.”': 10}]
# 5236 : [{'discords—why': 10}]
# 5244 : [{'anything’s': 10}]
# 5245 : [{'odd.”': 10}]
# 5251 : [{'Music—that’s': 10}]
# 5253 : [{'beauty—though': 10}, {'faculty—is': 10}]
# 5257 : [{'architecture.”': 10}]
# 5265 : [{'faculty—the': 10}, {'beauty—which': 10}]
# 5269 : [{'Nobody’s': 10}]
# 5270 : [{'finished—after': 10}]
# 5271 : [{'it—when': 10}]
# 5298 : [{'Paul’s—and': 10}]
# 5299 : [{'Paul’s.”': 10}]
# 5301 : [{'London.”': 10}]
# 5306 : [{'Fire.”': 10}]
# 5316 : [{'race—or': 10}, {'nearly—as': 10}]
# 5329 : [{'circumstances—undoubtedly': 10}]
# 5333 : [{'docet': 20}, {'—nothing': 10}]
# 5348 : [{'docet': 20}]
# 5357 : [{'Portland': 20}]
# 5362 : [{'Look.”': 20}]
# 5369 : [{'Portland': 20}]
# 5375 : [{'Charles': 20}]
# 5390 : [{'Goldsmiths’': 10}]
# 5410 : [{'base—the': 10}]
# 5425 : [{'booksellers’': 10}]
# 5428 : [{'Ludgate': 20}]
# 5430 : [{'Ditch—widened': 10}]
# 5431 : [{'stuff—leaps': 10}]
# 5434 : [{'Holborn': 10}]
# 5436 : [{'Lincoln’s': 10}]
# 5446 : [{'Tritons—river': 10}]
# 5447 : [{'Polyolbion': 10}, {'beaches—bathing': 10}]
# 5451 : [{'India': 20}]
# 5454 : [{'Charles': 20}]
# 5458 : [{'Blackfriars': 20}]
# 5475 : [{'XII': 10}]
# 5486 : [{'But—you': 10}, {'know—gentler——”': 10}]
# 5487 : [{'sweeter.”': 10}]
# 5498 : [{'curled—oh': 10}, {'gravely—with': 10}]
# 5505 : [{'Beaver.”': 10}]
# 5515 : [{'Lyons’s': 10}]
# 5536 : [{'hunter’s': 10}]
# 5545 : [{'Molly.”': 10}]
# 5551 : [{'amusing.”': 10}]
# 5568 : [{'Stanley': 10}]
# 5578 : [{'meant.”': 10}]
# 5580 : [{'Didn’t': 20}]
# 5582 : [{'least.”': 20}]
# 5587 : [{'11th': 10}, {'November': 20}, {'etc': 10}]
# 5596 : [{'rights—drunk': 10}]
# 5600 : [{'septically': 10}]
# 5611 : [{'tried.”': 10}]
# 5616 : [{'brutes.”': 10}]
# 5618 : [{'Anch’': 10}]
# 5627 : [{'different.”': 10}]
# 5631 : [{'stupid.”': 10}]
# 5633 : [{'is.”': 20}]
# 5638 : [{'Boots’': 10}]
# 5640 : [{'love.”': 20}]
# 5644 : [{'oughtn’t': 10}]
# 5646 : [{'country—and': 10}]
# 5648 : [{'time—she': 10}]
# 5653 : [{'paint.”': 10}]
# 5655 : [{'fields.”': 10}]
# 5660 : [{'butcher’s': 20}]
# 5662 : [{'Flowers—he': 10}]
# 5663 : [{'year’s': 10}]
# 5667 : [{'mother’s': 20}]
# 5677 : [{'Hindhead': 10}, {'Frensham': 10}]
# 5678 : [{'Big.”': 10}]
# 5696 : [{'ridiculous.”': 10}]
# 5702 : [{'kiss—more': 10}]
# 5703 : [{'embracement—that': 10}]
# 5707 : [{'Hammersmith': 10}, {'Broadway': 10}]
# 5713 : [{'now——”': 10}]
# 5719 : [{'promise.”': 10}]
# 5728 : [{'‘sweeter’': 10}]
# 5735 : [{'yesterday.”': 10}]
# 5736 : [{'wretched.”': 10}]
# 5738 : [{'forgiving.”': 10}]
# 5741 : [{'sure.”': 20}]
# 5743 : [{'see——”': 10}]
# 5747 : [{'I.”': 10}]
# 5751 : [{'green—after': 10}]
# 5766 : [{'Deliberately—to': 10}]
# 5768 : [{'head—round': 10}, {'continually.”': 10}]
# 5774 : [{'sometimes—not': 10}, {'sleep—the': 10}]
# 5778 : [{'grows—a': 10}]
# 5794 : [{'daren’t': 20}]
# 5805 : [{'commit.”': 10}]
# 5824 : [{'unpetal': 10}, {'—every': 10}]
# 5826 : [{'prega': 10}, {'sputare': 10}]
# 5827 : [{'oneself—dutifully—in': 10}]
# 5831 : [{'111.”': 10}]
# 5836 : [{'gardens——”': 10}]
# 5846 : [{'movement.”': 10}]
# 5855 : [{'fly.”': 10}]
# 5859 : [{'late.”': 20}, {'see”': 10}]
# 5869 : [{'XIII': 10}]
# 5875 : [{'minuetto': 20}]
# 5876 : [{'begins.”': 10}]
# 5879 : [{'lovely.”': 20}]
# 5887 : [{'minuetto': 20}, {'Mozart’s': 20}]
# 5892 : [{'Minuetto—all': 10}]
# 5903 : [{'sentimental.”': 10}]
# 5906 : [{'Albert': 20}]
# 5937 : [{'measure—a': 10}]
# 5947 : [{'Garofalo': 10}]
# 5948 : [{'electroliers': 10}]
# 5950 : [{'Peperkoek': 10}]
# 5953 : [{'Knoedler': 10}]
# 5956 : [{'Jenkins': 10}]
# 5957 : [{'Sclopis’s': 10}]
# 5961 : [{'circumstances—the': 10}]
# 5962 : [{'embarrassing—it': 10}]
# 5965 : [{'hearing.”': 10}]
# 5969 : [{'‘Your': 10}]
# 5970 : [{'Row.’': 10}]
# 5987 : [{'there.”': 20}]
# 5988 : [{'there—after': 10}]
# 5993 : [{'melancholy—like': 10}]
# 5997 : [{'dull.”': 10}]
# 6010 : [{'together—and': 10}]
# 6011 : [{'unreal.”': 20}]
# 6013 : [{'real.”': 20}]
# 6018 : [{'it’ll': 20}]
# 6042 : [{'real.”': 20}]
# 6047 : [{'stanchlessly': 20}]
# 6116 : [{'unresisting': 10}]
# 6132 : [{'Mozart’s': 20}]
# 6149 : [{'XIV': 10}]
# 6171 : [{'vacuum—it': 10}]
# 6196 : [{'cigary': 10}]
# 6200 : [{'ah’m.”': 10}]
# 6206 : [{'dipsos—thoroughly': 10}]
# 6215 : [{'Leith': 10}]
# 6216 : [{'Holmbury': 10}, {'Ivinghoe': 10}, {'Beacon—any': 10}]
# 6230 : [{'unfortunate.”': 10}]
# 6235 : [{'meeting.”': 10}]
# 6239 : [{'Providence.”': 10}]
# 6264 : [{'Merci': 10}]
# 6267 : [{'luncheon.”': 10}]
# 6271 : [{'Sussex': 10}]
# 6287 : [{'astonished.”': 10}]
# 6294 : [{'Verrey’s.”': 10}]
# 6300 : [{'articulo': 10}]
# 6301 : [{'Verrey’s': 20}]
# 6306 : [{'hints—in': 10}]
# 6312 : [{'hollyhocks—though': 10}]
# 6314 : [{'—happily': 10}]
# 6319 : [{'lanes—or': 10}]
# 6321 : [{'it—they': 10}]
# 6324 : [{'‘Tweedly': 10}, {'weedly': 10}]
# 6325 : [{'weedledy': 10}, {'dee.’”': 10}]
# 6327 : [{'however.”': 10}]
# 6339 : [{'let’s': 10}, {'wire.”': 10}]
# 6342 : [{'Wren’s': 10}]
# 6354 : [{'”—no': 10}]
# 6370 : [{'clown’s': 10}]
# 6374 : [{'Giudicato': 10}, {'guarabile': 10}, {'giorni': 10}]
# 6376 : [{'colpo': 10}, {'rivoltella': 10}]
# 6377 : [{'eye—all': 10}, {'Misericordia': 10}]
# 6380 : [{'complications.”': 10}]
# 6382 : [{'pavement’s': 10}]
# 6384 : [{'walk.”': 10}]
# 6386 : [{'Verrey’s': 20}]
# 6388 : [{'flea.”': 10}]
# 6398 : [{'Lascelles': 20}]
# 6403 : [{'over.”': 20}]
# 6405 : [{'Giovanni': 10}, {'ci': 20}]
# 6406 : [{'darem': 20}, {'dirai': 10}, {'Vieni': 10}, {'lontano': 10}, {'Partiam': 10}]
# 6407 : [{'da': 10}, {'vorrei': 20}]
# 6408 : [{'vorrei': 20}, {'trema': 10}, {'il': 20}, {'.’': 10}, {'away.”': 20}]
# 6410 : [{'Felice': 20}, {'sarei': 20}]
# 6415 : [{'hortus': 10}, {'siccus': 10}]
# 6420 : [{'virgin—what': 10}]
# 6427 : [{'deliriums.”': 10}]
# 6432 : [{'yours.”': 10}]
# 6435 : [{'much.”': 20}]
# 6437 : [{'coherence.”': 10}]
# 6446 : [{'tolerable.”': 10}]
# 6451 : [{'Orvieto': 10}]
# 6452 : [{'Italy': 20}]
# 6454 : [{'Rome.”': 10}]
# 6455 : [{'disillusion.”': 10}]
# 6460 : [{'afternoon.”': 20}]
# 6463 : [{'fatiguedly': 10}]
# 6474 : [{'believe.”': 20}]
# 6476 : [{'Nothing’s': 10}, {'be.”': 20}]
# 6493 : [{'Vivamus': 20}, {'mea': 20}, {'Lesbia': 20}]
# 6494 : [{'my”—he': 10}]
# 6495 : [{'accident.”': 10}]
# 6502 : [{'tea——”': 10}]
# 6503 : [{'standstill—“after': 10}]
# 6504 : [{'stimulant”—he': 10}, {'door—“we': 10}]
# 6505 : [{'better.”': 10}]
# 6511 : [{'Dufy—racehorses': 10}]
# 6514 : [{'Balla': 10}]
# 6527 : [{'Blüthner': 10}]
# 6528 : [{'play.”': 20}]
# 6541 : [{'eyes—ah': 10}]
# 6544 : [{'try.”': 10}]
# 6557 : [{'anapæsts': 10}]
# 6564 : [{'them—for': 10}]
# 6579 : [{'salvation.”': 20}]
# 6584 : [{'ci': 20}, {'darem': 20}]
# 6586 : [{'Zerlina': 20}]
# 6587 : [{'shadow.”': 10}]
# 6590 : [{'Felice': 20}, {'sarei': 20}, {'Batti': 10}, {'batti': 10}]
# 6591 : [{'Mazetto': 10}, {'Zerlina': 20}]
# 6595 : [{'like——”': 10}]
# 6601 : [{'questioningly': 10}]
# 6607 : [{'XV': 10}]
# 6613 : [{'angel’s': 10}, {'Teresa’s': 10}]
# 6614 : [{'ecstasiated': 10}]
# 6615 : [{'Mohammedan': 10}]
# 6627 : [{'alone—for': 10}]
# 6630 : [{'heart—broke': 10}]
# 6635 : [{'Wednesday': 20}]
# 6636 : [{'Bengal.”': 10}]
# 6640 : [{'désesperés': 10}, {'sont': 20}, {'j’en': 10}, {'sais': 10}, {'d’immortels': 10}]
# 6641 : [{'sont': 20}, {'sanglots': 10}]
# 6642 : [{'nothing.”': 20}]
# 6647 : [{'Charybdis': 10}]
# 6650 : [{'trotting.”': 10}]
# 6658 : [{'Florentine': 10}]
# 6660 : [{'Arabs': 10}, {'untravestied': 10}]
# 6662 : [{'‘Artistic.’': 10}]
# 6668 : [{'tune.”': 10}]
# 6682 : [{'‘finished’': 10}]
# 6683 : [{'C’est': 20}]
# 6684 : [{'exercice': 10}, {'très': 10}, {'gracieux': 10}, {'puis': 20}]
# 6685 : [{'puis': 20}, {'dévelope': 10}, {'bassin': 20}]
# 6686 : [{'Quel': 10}, {'bassin': 20}]
# 6689 : [{'greyhound’s': 20}]
# 6696 : [{'book.”': 20}]
# 6705 : [{'greyhound’s': 20}]
# 6711 : [{'George’s': 10}, {'Hanover': 20}]
# 6712 : [{'—oh': 10}, {'—with': 20}]
# 6715 : [{'Wednesday': 20}, {'Lycidas': 10}]
# 6718 : [{'all—nil': 10}]
# 6719 : [{'years—and': 10}]
# 6722 : [{'Where’s': 20}]
# 6727 : [{'myself.”': 20}]
# 6746 : [{'Bengal': 10}]
# 6755 : [{'XVI': 10}]
# 6760 : [{'room—“making': 10}]
# 6761 : [{'before—and': 10}]
# 6762 : [{'unreal.”': 20}]
# 6765 : [{'bed—on': 10}, {'perhaps—the': 10}]
# 6775 : [{'septicæmia': 10}]
# 6820 : [{'Fadingly': 10}]
# 6828 : [{'somebody’s': 10}]
# 6833 : [{'spectator’s': 10}]
# 6860 : [{'milk—her': 10}]
# 6861 : [{'Jesus': 10}]
# 6862 : [{'galactagogue': 10}]
# 6879 : [{'cow.”': 10}]
# 6884 : [{'Christmas': 20}]
# 6885 : [{'Leno’s': 10}]
# 6886 : [{'them—every': 10}]
# 6887 : [{'Drury': 10}]
# 6893 : [{'w.c': 10}]
# 6894 : [{'feet—and': 10}]
# 6895 : [{'great—in': 10}]
# 6896 : [{'Yorick': 10}]
# 6902 : [{'entr’actes': 20}]
# 6904 : [{'entr’acte': 20}]
# 6905 : [{'favourable': 20}]
# 6914 : [{'here’s': 10}]
# 6922 : [{'Sparta': 10}]
# 6929 : [{'slug—and': 10}]
# 6952 : [{'Catherine': 20}, {'Siena': 10}]
# 6953 : [{'plumbless': 10}]
# 6956 : [{'crêpe': 10}]
# 6959 : [{'July': 10}]
# 6969 : [{'If—if': 10}, {'did—well': 10}]
# 6970 : [{'servant’s': 20}]
# 6989 : [{'saint’s': 20}]
# 7001 : [{'love—I——': 10}]
# 7006 : [{'groom’s': 10}]
# 7029 : [{'who’s': 10}]
# 7140 : [{'Diabelli’s': 10}]
# 7169 : [{'drunk.”': 10}]
# 7176 : [{'Hellenic': 10}]
# 7184 : [{'Where’s': 20}]
# 7186 : [{'physiologue’s': 10}]
# 7187 : [{'wife.”': 10}]
# 7192 : [{'play.”': 20}]
# 7201 : [{'Dante': 20}]
# 7202 : [{'Virgil': 10}]
# 7203 : [{'tour—or': 10}]
# 7204 : [{'Alighieri': 10}]
# 7205 : [{'Paolo': 10}, {'Francesca.”': 10}]
# 7207 : [{'uncomprehendingly': 10}]
# 7209 : [{'entr’actes': 20}]
# 7211 : [{'entr’acte': 20}]
# 7216 : [{'another.”': 10}]
# 7227 : [{'Milton': 10}]
# 7229 : [{'Diabelli': 10}, {'Brunelleschi’s': 10}]
# 7230 : [{'Cléo': 10}, {'Mérode’s': 10}]
# 7231 : [{'Greeks': 20}]
# 7234 : [{'Jupiter': 20}]
# 7238 : [{'Europa': 10}]
# 7239 : [{'Leda': 10}, {'Danae': 10}]
# 7243 : [{'doghole': 10}]
# 7245 : [{'runged': 10}]
# 7246 : [{'acrobacy': 10}]
# 7264 : [{'neck’s': 10}]
# 7278 : [{'over.”': 20}]
# 7289 : [{'Socrates': 10}]
# 7304 : [{'dung.”': 10}]
# 7315 : [{'Michelangelo’s': 20}, {'‘Night’': 10}, {'Medici': 10}]
# 7321 : [{'boire': 20}, {'boire': 20}]
# 7326 : [{'Dante': 20}, {'building.”': 10}]
# 7331 : [{'one.”': 20}]
# 7333 : [{'Can’t': 20}]
# 7334 : [{'least.”': 20}]
# 7341 : [{'she’ll': 10}]
# 7343 : [{'mou': 10}, {'sas': 10}, {'agapo': 10}]
# 7354 : [{'Chopin’s': 10}, {'‘Funeral': 10}]
# 7355 : [{'March’': 10}]
# 7360 : [{'Street.”': 10}]
# 7364 : [{'did.”': 10}]
# 7373 : [{'wine.”': 10}]
# 7375 : [{'Diuretic.”': 10}]
# 7377 : [{'whisky.”': 10}]
# 7380 : [{'Fascisti': 10}, {'Giovinezza': 10}, {'giovinezza': 10}, {'bellezza': 10}]
# 7394 : [{'Eno’s': 10}]
# 7396 : [{'Grimaldi': 20}]
# 7397 : [{'Grimaldi.’': 10}]
# 7405 : [{'chemin': 10}]
# 7409 : [{'Hogarthian.”': 10}]
# 7413 : [{'know—not': 10}, {'either.”': 10}]
# 7424 : [{'story.”': 20}]
# 7437 : [{'Expiringly': 10}]
# 7448 : [{'Grimaldi': 20}]
# 7452 : [{'Towsing': 10}, {'Elizabethan': 20}]
# 7496 : [{'XVII': 10}]
# 7500 : [{'Lascelles': 20}]
# 7508 : [{'accident—though': 10}]
# 7509 : [{'darling—but': 10}]
# 7513 : [{'cottage—and': 10}, {'We’d': 20}]
# 7516 : [{'view—miles': 10}]
# 7520 : [{'ready—not': 10}]
# 7522 : [{'Hastings': 10}]
# 7537 : [{'‘accident': 10}, {'smashed—oh': 10}]
# 7539 : [{'it—why': 10}, {'‘a': 10}]
# 7540 : [{'thought—and': 10}]
# 7555 : [{'come—what': 10}]
# 7563 : [{'lightly—you': 10}]
# 7569 : [{'last—what': 10}]
# 7584 : [{'A.B.C': 10}]
# 7592 : [{'Viveash—ah': 10}]
# 7597 : [{'out—and': 10}]
# 7600 : [{'Hadn’t': 10}]
# 7610 : [{'She’d': 20}]
# 7614 : [{'doing—as': 10}]
# 7617 : [{'off—that': 10}]
# 7618 : [{'but—ultimate': 10}, {'taste—played': 10}]
# 7620 : [{'indisposed.”': 10}]
# 7645 : [{'world.”': 20}]
# 7663 : [{'burst.”': 10}]
# 7666 : [{'soothing.”': 10}]
# 7674 : [{'to.”': 20}]
# 7680 : [{'up.”': 20}]
# 7686 : [{'Hampstead': 20}]
# 7689 : [{'Jonah': 10}]
# 7698 : [{'present.”': 10}]
# 7701 : [{'cornland': 10}]
# 7703 : [{'gardens.”': 10}]
# 7710 : [{'increase.”': 10}]
# 7737 : [{'undone.”': 10}]
# 7745 : [{'only.”': 10}]
# 7751 : [{'brandy.”': 10}]
# 7754 : [{'flattering.”': 10}]
# 7757 : [{'sir.”': 20}]
# 7759 : [{'one.”': 20}]
# 7772 : [{'The—o—dore': 10}]
# 7788 : [{'station—which': 10}]
# 7802 : [{'clergymen’s': 10}]
# 7808 : [{'XVIII': 10}]
# 7830 : [{'dachshunds”': 10}]
# 7831 : [{'Milanese': 10}]
# 7832 : [{'marvellously': 20}, {'Selfridge': 10}]
# 7839 : [{'Soho': 20}]
# 7843 : [{'unconcealing': 10}]
# 7850 : [{'Windsor': 10}, {'Tintern': 10}]
# 7851 : [{'Albert’s': 10}, {'days—polishing': 10}]
# 7852 : [{'subject—the': 10}]
# 7853 : [{'‘Jus': 10}, {'Noctis': 20}, {'Seigneur’—“that': 10}]
# 7855 : [{'Dieu': 10}, {'Droit—de': 10}]
# 7859 : [{'Chesterton': 10}, {'Lord’s': 20}]
# 7864 : [{'Carthage': 10}]
# 7865 : [{'Lord’s': 20}, {'right—the': 10}]
# 7870 : [{'imaginations’': 20}]
# 7875 : [{'imaginations’': 20}]
# 7877 : [{'lascivious’': 10}, {'‘delicate': 10}]
# 7878 : [{'prurient’': 20}]
# 7880 : [{'prurient’': 20}]
# 7881 : [{'‘Pretty': 10}, {'prurient’—they': 10}, {'justes': 10}]
# 7889 : [{'housekeeper’s': 10}]
# 7895 : [{'vomitorium': 10}, {'Petronius': 10}]
# 7927 : [{'criticize.”': 10}]
# 7933 : [{'mur': 10}, {'derer': 10}, {'adul': 10}, {'terer—then': 10}]
# 7947 : [{'folie': 10}, {'terribiltà': 10}, {'——”': 20}]
# 7950 : [{'sympathetic.”': 10}]
# 7951 : [{'poutery': 10}]
# 7954 : [{'deep—for': 10}]
# 7955 : [{'long—that': 10}]
# 7957 : [{'Crébillon’s': 20}]
# 7959 : [{'Marie': 20}, {'Laurencin': 20}]
# 7964 : [{'Chelsea': 20}]
# 7968 : [{'Noctis': 20}]
# 7979 : [{'kind.”': 20}]
# 7985 : [{'work.”': 20}, {'designer.”': 10}]
# 7989 : [{'You—how': 10}]
# 7993 : [{'Noctis”': 10}]
# 8004 : [{'hobbledehoys.”': 10}]
# 8008 : [{'passion——But': 10}]
# 8009 : [{'creature’s': 10}]
# 8021 : [{'mistaken.”': 10}]
# 8030 : [{'apéritif': 10}]
# 8036 : [{'Viveash.”': 20}]
# 8047 : [{'one—she': 10}]
# 8049 : [{'disengagedly': 10}]
# 8066 : [{'Rowbotham': 10}]
# 8069 : [{'poet’s': 10}, {'Mercaptan—she': 10}]
# 8072 : [{'Philip': 10}, {'Patrick': 10}, {'Pendennis': 10}]
# 8074 : [{'‘Pasteur.’': 10}]
# 8077 : [{'floor—one': 10}]
# 8102 : [{'Paster”—for': 10}]
# 8116 : [{'them—Rosie': 10}]
# 8117 : [{'beard—neither': 10}]
# 8122 : [{'owe——': 10}]
# 8123 : [{'ask——': 10}]
# 8131 : [{'Mercaptan.”': 20}]
# 8137 : [{'enfin': 10}, {'que': 10}, {'demeure': 10}, {'se': 20}, {'trouve': 10}, {'effet': 10}]
# 8138 : [{'sure.”': 20}]
# 8144 : [{'—so': 10}]
# 8155 : [{'poeticus': 10}]
# 8156 : [{'Crébillon.”': 10}]
# 8161 : [{'Crébillon’s': 20}]
# 8170 : [{'book.”': 20}]
# 8171 : [{'hero’s': 10}]
# 8175 : [{'sofa’s': 10}, {'disappointments.”': 10}]
# 8180 : [{'quiproquo': 10}]
# 8184 : [{'mine.”': 20}]
# 8192 : [{'the—the': 10}]
# 8193 : [{'address.”': 10}]
# 8197 : [{'s—second': 10}]
# 8208 : [{'S—second': 10}, {'telegram.”': 10}]
# 8211 : [{'name.”': 10}]
# 8214 : [{'name—I': 10}, {'galantuomo': 10}]
# 8234 : [{'friends.”': 10}]
# 8236 : [{'laughed—the': 10}]
# 8237 : [{'Des': 10}, {'—with': 20}, {'‘e': 10}]
# 8241 : [{'Goldie.”': 10}]
# 8243 : [{'gentleman’s': 20}]
# 8246 : [{'I——”': 20}]
# 8249 : [{'possible.”': 10}]
# 8252 : [{'Paster.”': 10}]
# 8255 : [{'indiscreet—what': 10}]
# 8258 : [{'W—well': 10}]
# 8259 : [{'beard.”': 10}]
# 8266 : [{'joke.”': 10}]
# 8268 : [{'cœur': 10}]
# 8279 : [{'Marie': 20}, {'Laurencin': 20}, {'Du': 10}, {'Côté': 10}, {'Swann': 10}]
# 8280 : [{'Chelsea': 20}]
# 8292 : [{'snake’s': 10}]
# 8297 : [{'we——”': 10}]
# 8301 : [{'say.”': 20}]
# 8305 : [{'im': 10}]
# 8308 : [{'heart.’': 10}]
# 8316 : [{'sofa—a': 10}]
# 8318 : [{'sofa—lay': 10}]
# 8322 : [{'bientôt': 20}]
# 8335 : [{'CRÉBILLON': 10}]
# 8337 : [{'bientôt': 20}, {'—she': 10}]
# 8338 : [{'Noctis”—ah': 20}]
# 8342 : [{'myself”—Mr': 10}]
# 8343 : [{'it—“': 10}, {'l’esprit': 10}, {'d’escalier': 10}, {'galantes': 10}]
# 8363 : [{'She’s': 10}]
# 8374 : [{'if—if—if——': 10}]
# 8377 : [{'barrister’s': 10}]
# 8379 : [{'ago—during': 10}]
# 8440 : [{'classics.”': 10}]
# 8444 : [{'younger.”': 10}]
# 8453 : [{'’m': 10}]
# 8465 : [{'n—notice': 10}]
# 8471 : [{'civ—vilized': 20}]
# 8477 : [{'marriage.”': 10}]
# 8479 : [{'then—n': 10}]
# 8488 : [{'‘liked’': 10}]
# 8491 : [{'before—blind': 10}]
# 8497 : [{'husband’s': 10}, {'face—the': 10}]
# 8498 : [{'bristlingly': 10}, {'baby—also': 10}]
# 8506 : [{'persevere.”': 10}]
# 8515 : [{'speak.”': 10}]
# 8517 : [{'cher': 20}]
# 8519 : [{'Darby': 10}, {'Joan': 10}]
# 8521 : [{'life—naturally': 10}]
# 8522 : [{'way.”': 10}]
# 8527 : [{'civ—vilized': 20}]
# 8540 : [{'XIX': 10}]
# 8562 : [{'Carisbrooke': 10}]
# 8566 : [{'‘Where': 20}]
# 8568 : [{'‘Where': 20}]
# 8569 : [{'everything—the': 10}]
# 8585 : [{'country—you': 10}, {'remember—under': 10}, {'Hog’s': 20}]
# 8586 : [{'‘Hotel': 10}, {'Bull’—do': 10}]
# 8589 : [{'Hog’s': 20}]
# 8591 : [{'Pilgrims’': 10}]
# 8592 : [{'Puttenham': 10}]
# 8594 : [{'Compton': 10}]
# 8595 : [{'Cutt': 10}]
# 8596 : [{'Shackleford': 10}]
# 8602 : [{'Michelangelo’s': 20}]
# 8605 : [{'gets—why': 10}]
# 8608 : [{'Amor': 10}, {'dunque': 10}, {'tua': 10}, {'beltate': 10}]
# 8609 : [{'fortuna': 10}, {'durezza': 10}, {'disdegno': 10}]
# 8610 : [{'mal': 10}, {'colpa': 10}, {'destino': 10}, {'sorte': 10}]
# 8612 : [{'Se': 10}, {'dentro': 10}, {'tuo': 10}, {'morte': 20}, {'pietate': 10}]
# 8613 : [{'Porti': 10}, {'ch’l': 10}, {'ingegno': 20}]
# 8614 : [{'Non': 10}, {'sappia': 10}, {'ardendo': 10}, {'trarne': 10}, {'altro': 10}, {'che': 10}, {'morte': 20}]
# 8616 : [{'ingegno': 20}]
# 8622 : [{'at—and': 10}]
# 8626 : [{'Maupassant': 10}]
# 8627 : [{'rabbi’s': 10}]
# 8632 : [{'Myra—what': 10}]
# 8634 : [{'incomprehensible': 10}]
# 8637 : [{'rhodomontading': 10}]
# 8653 : [{'too—almost': 10}, {'sometimes—in': 10}]
# 8655 : [{'down—ah': 10}, {'—that': 10}]
# 8682 : [{'Selborne': 10}]
# 8683 : [{'‘Because': 10}]
# 8691 : [{'Lydgate': 10}]
# 8706 : [{'Herbert': 10}]
# 8710 : [{'interested.”': 10}]
# 8721 : [{'Derain': 20}]
# 8722 : [{'said—“of': 10}, {'Orpen.”': 10}]
# 8738 : [{'sorry.”': 10}]
# 8742 : [{'Lydgate—Mr': 10}]
# 8746 : [{'Owbridge’s': 10}]
# 8752 : [{'work”—he': 10}, {'Viveash—“I': 10}]
# 8773 : [{'XX': 10}]
# 8809 : [{'Coleman.”': 10}]
# 8812 : [{'wounds.”': 10}]
# 8822 : [{'war.”': 10}]
# 8831 : [{'consent—oh': 10}, {'reluctantly—to': 10}]
# 8842 : [{'Pimlico—to': 10}]
# 8844 : [{'—the': 20}]
# 8846 : [{'Noctis”—ah': 20}]
# 8851 : [{'Café': 10}, {'Royal—upstairs': 10}]
# 8862 : [{'being.”': 10}]
# 8864 : [{'boors.”': 10}]
# 8865 : [{'ploughboy': 10}]
# 8880 : [{'Leonardo’s': 10}]
# 8885 : [{'accidents.”': 10}]
# 8892 : [{'you—you': 10}]
# 8895 : [{'‘we’': 10}]
# 8898 : [{'and—how': 10}, {'—my': 10}]
# 8902 : [{'Spoonerismus': 10}, {'fashion.”': 10}]
# 8909 : [{'homœopathic': 10}]
# 8910 : [{'Leonardo': 20}]
# 8920 : [{'Odo': 20}, {'Cluny': 10}]
# 8921 : [{'saccus': 10}, {'stercoris': 20}]
# 8922 : [{'quis': 10}, {'enim': 10}, {'considerat': 10}]
# 8923 : [{'ventrem': 10}, {'lateant': 10}, {'sordes': 10}, {'reperiet': 10}]
# 8924 : [{'nec': 10}, {'extremis': 10}, {'digitis': 10}, {'flegma': 10}]
# 8925 : [{'vel': 10}, {'stercus': 10}, {'tangere': 10}, {'patimur': 10}, {'ipsum': 10}, {'stercoris': 20}, {'saccum': 10}, {'amplecti': 10}]
# 8926 : [{'desideramus': 10}]
# 8929 : [{'Look.”': 20}]
# 8931 : [{'Odo': 20}]
# 8934 : [{'conceal.”': 10}]
# 8937 : [{'Cossack’s': 20}]
# 8947 : [{'esca': 10}, {'vermium': 10}, {'pulveris': 10}]
# 8949 : [{'tripes—what': 10}]
# 8958 : [{'unpl—leasant': 10}, {'is.”': 20}]
# 8962 : [{'beard—imagine': 10}]
# 8967 : [{'naturel': 20}]
# 8970 : [{'m—much': 10}]
# 8982 : [{'Ghost—if': 10}]
# 8984 : [{'defæcation': 10}, {'a——”': 20}]
# 8991 : [{'indifferent.”': 10}]
# 8996 : [{'arm.”': 10}]
# 9001 : [{'significant.”': 10}]
# 9018 : [{'curiosity.”': 10}]
# 9025 : [{'A.M.O.R': 10}]
# 9026 : [{'C.A.S.T.I.T.A.S': 10}]
# 9032 : [{'times.”': 10}]
# 9035 : [{'Gladstone”—he': 10}]
# 9036 : [{'again—“surely': 10}]
# 9047 : [{'Cossack’s': 20}]
# 9065 : [{'XXI': 10}]
# 9072 : [{'Pyramidon': 10}]
# 9074 : [{'Blanche': 10}]
# 9079 : [{'story.”': 20}]
# 9083 : [{'Myra.”': 10}]
# 9084 : [{'patient’s': 10}]
# 9105 : [{'existence.”': 10}]
# 9108 : [{'phrases.”': 10}]
# 9113 : [{'vacuum.”': 10}]
# 9125 : [{'afraid.”': 10}]
# 9141 : [{'head.”': 10}]
# 9145 : [{'business.”': 10}]
# 9153 : [{'England.”': 10}]
# 9160 : [{'listen—to': 10}]
# 9169 : [{'Umbilikoff': 10}]
# 9170 : [{'bladders—like': 10}]
# 9171 : [{'sago—are': 10}]
# 9173 : [{'moon’s': 10}]
# 9174 : [{'Scorpio—he': 10}]
# 9182 : [{'Nash': 10}]
# 9192 : [{'Capricorn': 20}, {'Rubens': 10}]
# 9194 : [{'Nemo': 10}]
# 9199 : [{'C’est': 20}, {'—Gumbril': 10}]
# 9204 : [{'flowers—a': 10}]
# 9205 : [{'overwing': 10}]
# 9207 : [{'Capricorn': 20}]
# 9210 : [{'Jewesses': 10}]
# 9218 : [{'Piero': 10}, {'della': 20}, {'Francesca’s': 10}, {'San': 20}, {'Sepolcro': 10}]
# 9220 : [{'Scriabine': 10}, {'Tschaikovsky': 10}, {'jours': 20}]
# 9221 : [{'Marchand': 10}]
# 9229 : [{'Connie': 10}, {'Asticot': 10}, {'Jim': 20}, {'Baum': 10}]
# 9230 : [{'Lola': 10}, {'Knopf': 10}, {'Margherita': 10}]
# 9231 : [{'Radicofani': 10}, {'Meyer': 10}, {'Cavey': 10}]
# 9232 : [{'Nobes': 10}]
# 9248 : [{'They’ll': 20}, {'Romain': 10}, {'Rolland': 10}]
# 9261 : [{'love—m’yes': 10}, {'m’yes': 10}, {'met—I': 10}]
# 9269 : [{'Didn’t': 20}]
# 9271 : [{'all—everything': 10}]
# 9277 : [{'‘This': 20}, {'book.’': 10}, {'Scotsman': 10}, {'‘This': 20}]
# 9278 : [{'psychology.’': 10}, {'Darlington': 10}, {'‘Mr': 10}]
# 9279 : [{'Xavier': 10}]
# 9280 : [{'Rochester': 10}]
# 9281 : [{'Hume.’': 10}]
# 9283 : [{'Herr': 10}, {'Jesu': 10}, {'Nimmernein': 10}]
# 9285 : [{'consider.”': 10}]
# 9290 : [{'tip”—he': 10}]
# 9291 : [{'fingers—“caress': 10}, {'Z—zip.”': 10}]
# 9299 : [{'anything.”': 10}]
# 9302 : [{'Versiam’': 10}, {'piena': 10}, {'il': 20}, {'generoso': 10}, {'umor': 10}]
# 9303 : [{'Robert': 10}]
# 9310 : [{'Vitus’s': 10}, {'Shaftesbury': 10}]
# 9315 : [{'lovely.”': 20}]
# 9322 : [{'twitches—what': 10}]
# 9329 : [{'opinion.”': 10}]
# 9330 : [{'Eppur’': 10}, {'muove': 10}, {'—I': 10}, {'Galileo': 10}]
# 9331 : [{'horrible.”': 10}]
# 9343 : [{'writing—writing': 10}]
# 9346 : [{'yesterday’s': 10}]
# 9354 : [{'bed’s': 10}]
# 9373 : [{'coroner’s': 10}]
# 9396 : [{'street.”': 10}]
# 9401 : [{'light.”': 10}]
# 9405 : [{'poetry.”': 10}]
# 9410 : [{'poet.”': 10}]
# 9412 : [{'Il': 10}, {'Poeta': 10}, {'—capital': 10}, {'d’Annunzio': 20}]
# 9413 : [{'d’Annunzio': 20}]
# 9414 : [{'Corriere': 10}]
# 9415 : [{'della': 20}]
# 9417 : [{'Fioretti': 10}]
# 9418 : [{'Casimir.”': 20}]
# 9425 : [{'contemptuously—as': 10}]
# 9426 : [{'practice—it': 10}]
# 9428 : [{'failure.”': 10}]
# 9433 : [{'pocket.”': 10}]
# 9435 : [{'he’ll': 20}]
# 9436 : [{'suggestion.”': 10}]
# 9439 : [{'nothing’s': 10}]
# 9445 : [{'something.”': 10}]
# 9450 : [{'Charles’s': 10}, {'spaniel—or': 10}]
# 9452 : [{'go.”': 10}]
# 9455 : [{'ill.”': 10}, {'Hush.”': 20}]
# 9458 : [{'horse’s': 10}]
# 9462 : [{'out.”': 20}]
# 9466 : [{'Mercaptan.”': 20}]
# 9475 : [{'voices—at': 10}, {'well’s': 20}]
# 9476 : [{'well’s': 20}]
# 9489 : [{'Burlington': 10}, {'Sandeman’s': 10}]
# 9495 : [{'trees.”': 10}]
# 9511 : [{'Oxhanger': 20}]
# 9513 : [{'‘Loves': 10}, {'Pachyderms’': 10}]
# 9515 : [{'species—the': 10}]
# 9517 : [{'others’': 10}, {'‘responsive': 10}, {'‘to': 10}]
# 9518 : [{'reason.’': 10}]
# 9520 : [{'steatocephali': 10}, {'acephali': 10}]
# 9521 : [{'theolaters': 10}, {'Judæorhynci—busy': 10}]
# 9522 : [{'Russians': 20}]
# 9523 : [{'Oxhanger': 20}]
# 9527 : [{'Maisie': 20}, {'Furlonger': 20}]
# 9529 : [{'Speegle’s': 10}]
# 9532 : [{'N’you’re': 10}, {'n’just': 10}, {'n’your': 10}]
# 9533 : [{'experiences.”': 10}]
# 9535 : [{'laugh—squeal': 10}]
# 9536 : [{'together—had': 10}]
# 9540 : [{'Maisie': 20}, {'Furlonger': 20}]
# 9542 : [{'Greece': 10}]
# 9565 : [{'cheerful.”': 10}]
# 9567 : [{'Victoria.”': 10}]
# 9582 : [{'syrup.”': 10}]
# 9596 : [{'Ingres—but': 10}]
# 9597 : [{'boa—presented': 10}]
# 9600 : [{'round—to': 10}]
# 9602 : [{'indeed—the': 10}]
# 9627 : [{'Theodore’s': 10}]
# 9637 : [{'towsers': 10}]
# 9638 : [{'demon’s': 10}]
# 9655 : [{'them—and': 10}]
# 9660 : [{'Hoskyns': 10}]
# 9671 : [{'‘You’ll': 10}]
# 9682 : [{'bed.”': 20}]
# 9684 : [{'heart.”': 20}]
# 9702 : [{'—only': 10}]
# 9710 : [{'shameful.”': 20}]
# 9721 : [{'Magdalen.”': 10}]
# 9726 : [{'unnecessary.”': 10}]
# 9728 : [{'away.”': 20}]
# 9740 : [{'intended.”': 10}]
# 9748 : [{'Circus.”': 10}]
# 9750 : [{'farther.”': 10}]
# 9752 : [{'much.”': 20}]
# 9757 : [{'driving’s': 10}]
# 9770 : [{'flick—yes': 10}]
# 9771 : [{'Genuinely.”': 10}]
# 9774 : [{'minute.”': 10}]
# 9776 : [{'Appenrodt’s': 10}]
# 9797 : [{'Jaeger.”': 10}]
# 9799 : [{'there’d': 10}]
# 9801 : [{'They’ve': 20}]
# 9803 : [{'marches—whether': 10}]
# 9804 : [{'Kilburn': 10}, {'Golders': 10}, {'Clapham': 10}]
# 9805 : [{'Sydenham': 10}]
# 9811 : [{'tell.”': 10}]
# 9813 : [{'Children—that': 10}]
# 9819 : [{'perhaps—she': 10}]
# 9825 : [{'Maida': 20}]
# 9831 : [{'life—then': 10}]
# 9844 : [{'’ospital.”': 10}]
# 9848 : [{'’er': 20}]
# 9849 : [{'dinner.”': 10}]
# 9853 : [{'Pimlico.”': 10}]
# 9857 : [{'Toto.”': 10}]
# 9859 : [{'’adn’t': 10}]
# 9860 : [{'’er': 20}, {'sir.”': 20}]
# 9864 : [{'forget.”': 20}]
# 9875 : [{'Senior’s': 20}]
# 9882 : [{'Something—perhaps': 10}]
# 9885 : [{'together—would': 10}]
# 9886 : [{'voices—for': 10}]
# 9890 : [{'something—something': 10}]
# 9898 : [{'delighted.”': 10}]
# 9902 : [{'Enthusiastically': 10}]
# 9904 : [{'assembled—goodness': 10}]
# 9905 : [{'—they': 20}]
# 9914 : [{'conclusion.”': 10}]
# 9919 : [{'animals.”': 10}]
# 9923 : [{'mind—things': 10}]
# 9926 : [{'Niagara': 10}]
# 9932 : [{'people—that': 10}]
# 9939 : [{'‘Rule': 10}, {'Britannia’': 10}, {'Bach’s': 10}]
# 9941 : [{'algebraical': 10}]
# 9954 : [{'Hush.”': 20}]
# 9962 : [{'They’ve': 20}, {'asleep.”': 10}]
# 9970 : [{'worse.”': 10}]
# 9972 : [{'Senior’s': 20}]
# 9973 : [{'archiducal': 10}]
# 9975 : [{'vin': 10}, {'ordinaire': 10}]
# 9979 : [{'evening—very': 10}]
# 9987 : [{'anything—even': 10}]
# 10008 : [{'She’d': 20}, {'it—except': 10}]
# 10021 : [{'son’s': 20}]
# 10027 : [{'housemaid’s': 10}]
# 10029 : [{'Albert': 20}, {'they’ve': 20}]
# 10033 : [{'affection—no': 10}]
# 10035 : [{'son—with': 10}]
# 10045 : [{'Museum.”': 10}]
# 10056 : [{'books—in': 10}, {'quos': 10}, {'legimus': 10}, {'cacantes': 10}]
# 10061 : [{'Southwark': 10}]
# 10065 : [{'he’ll': 20}]
# 10070 : [{'laboratory.”': 10}]
# 10081 : [{'XXII': 10}]
# 10097 : [{'Gulliver': 10}, {'Brobdingnag': 10}]
# 10123 : [{'Lancing’s': 20}]
# 10125 : [{'sweatdrops': 10}]
# 10139 : [{'Swindon': 10}]
# 10140 : [{'Cambridge': 10}]
# 10141 : [{'Harwich': 10}]
# 10142 : [{'Winchester': 10}]
# 10143 : [{'Arundel': 10}]
# 10147 : [{'swayingly': 10}]
# 10177 : [{'enough—he': 10}]
# 10180 : [{'much—he': 10}]
# 10181 : [{'himself—all': 10}]
# 10182 : [{'useless—in': 10}]
# 10187 : [{'proportion.”': 20}]
# 10192 : [{'Dover': 20}]
# 10193 : [{'Dover': 20}]
# 10198 : [{'him—a': 10}]
# 10203 : [{'four—furiously': 10}]
# 10210 : [{'four—he': 10}]
# 10226 : [{'pullet.”': 10}]
# 10241 : [{'Steinach': 10}]
# 10242 : [{'Lancing’s': 20}]
# 10261 : [{'Blackfriars': 20}]
# 10265 : [{'stanchlessly': 20}]
# 10281 : [{'Amiens': 10}]
# 10288 : [{'Hampstead': 20}]
# 10289 : [{'Cotton.”': 10}]
# 10292 : [{'MORRISON': 10}, {'GIBB': 10}, {'LTD': 10}, {'EDINBURGH': 10}]
# 10299 : [{'TRANSCRIBER’S': 10}]
# 10319 : [{'Tonsing': 20}]
# 10322 : [{'Internet': 20}]
# 10360 : [{'1.A': 10}]
# 10363 : [{'trademark/copyright': 10}]
# 10372 : [{'1.B': 10}]
# 10377 : [{'1.C': 20}]
# 10380 : [{'1.E': 20}]
# 10382 : [{'1.C': 20}]
# 10383 : [{'PGLAF': 10}]
# 10399 : [{'1.D': 10}]
# 10409 : [{'1.E': 20}]
# 10426 : [{'1.E.2': 10}]
# 10437 : [{'1.E.3': 10}]
# 10445 : [{'1.E.4': 10}]
# 10449 : [{'1.E.5': 10}]
# 10455 : [{'1.E.6': 10}]
# 10459 : [{'ASCII': 20}]
# 10464 : [{'ASCII': 20}]
# 10475 : [{'20%': 10}]
# 10489 : [{'s/he': 10}]
# 10508 : [{'LLC': 10}]
# 10511 : [{'1.F': 10}]
# 10513 : [{'1.F.1': 10}]
# 10524 : [{'1.F.2': 10}]
# 10551 : [{'1.F.4': 10}]
# 10556 : [{'1.F.5': 10}]
# 10562 : [{'unenforceability': 10}]
# 10565 : [{'1.F.6': 10}]
# 10599 : [{'Mississippi': 10}]
# 10600 : [{'EIN': 10}]
# 10605 : [{'Fairbanks': 20}]
# 10606 : [{'PO': 10}, {'Fairbanks': 20}, {'AK': 10}]
# 10615 : [{'Gregory': 10}, {'Newby': 10}]
# 10627 : [{'$1': 10}, {'$5': 10}]
# 10628 : [{'IRS': 10}]
# 10655 : [{'Michael': 10}]
# 10667 : [{'PG': 10}]
# CPU times: user 762 ms, sys: 141 ms, total: 902 ms
# Wall time: 826 ms

# %% [markdown]
# ## Feedback
# _Please leave this cell. The marker will write feedback here._

# %%
# Please leave this cell.
# The marker will fill in your grade here.
Q3_GRADE = None
